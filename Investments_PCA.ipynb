# %% [markdown]
# # Investments Principal Component Analysis (PCA) and Hierarchical Clustering

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
from sklearn.decomposition import PCA
import statsmodels.formula.api as smf
from sklearn.metrics import (r2_score, mean_squared_error, mean_squared_log_error, mean_absolute_error)
from sklearn.preprocessing import PowerTransformer
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import MiniBatchKMeans, AgglomerativeClustering
from IPython.display import display

# Import investments dataframe
investments=pd.read_csv('investments.csv')

# %%
investments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                905 non-null    object
#  1   account_id                  905 non-null    int64
#  2   Year                        905 non-null    int64
#  3   incorporated_country        905 non-null    object
#  4   Primary activity            905 non-null    object
#  5   Primary sector              905 non-null    object
#  6   Market_Cap_USD              810 non-null    float64
#  7   Third_party_verification    904 non-null    object
#  8   Revenue_USD                 824 non-null    float64
#  9   ebitda_USD                  824 non-null    float64
#  10  grossProfit_USD             824 non-null    float64
#  11  netIncome_USD               824 non-null    float64
#  12  cashAndCashEquivalents_USD  824 non-null    float64
#  13  shortTermInvestments_USD    824 non-null    float64
#  14  longTermInvestments_USD     824 non-null    float64
#  15  totalAssets_USD             824 non-null    float64
#  16  totalLiabilities_USD        824 non-null    float64
#  17  totalInvestments_USD        824 non-null    float64
#  18  totalDebt_USD               824 non-null    float64
#  19  totalEquity_USD             824 non-null    float64
#  20  Scope_3_emissions_type      905 non-null    object
#  21  Scope_3_emissions_amount    905 non-null    float64
#  22  scope_1_2_emissions_amount  904 non-null    float64
#  23  Year_sq                     905 non-null    int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 169.8+ KB

# %%
investments.head()
# Out:
#                account_name  account_id  Year incorporated_country  \
# 0                     Aptiv        4407  2018       United Kingdom
# 1  Associated British Foods        1085  2018       United Kingdom
# 2           GlaxoSmithKline        7374  2018       United Kingdom
# 3                Kingfisher       10156  2018       United Kingdom
# 4      Lloyds Banking Group       10781  2018       United Kingdom
#
#        Primary activity                     Primary sector  Market_Cap_USD  \
# 0  Electrical equipment  Electrical & electronic equipment    1.595156e+10
# 1        Apparel stores               Discretionary retail    2.051429e+10
# 2       Pharmaceuticals                   Biotech & pharma    7.508927e+10
# 3     Specialist retail               Discretionary retail    5.248698e+09
# 4                 Banks                 Financial services    5.110653e+10
#
#                             Third_party_verification   Revenue_USD  \
# 0           No third-party verification or assurance  1.443500e+10
# 1  Third-party verification or assurance process ...  1.977898e+10
# 2  Third-party verification or assurance process ...  3.914267e+10
# 3  Third-party verification or assurance process ...  1.483995e+10
# 4  Third-party verification or assurance process ...  2.357882e+10
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 1  2.363470e+09  ...             3.429000e+08     1.738884e+10
# 2  9.344660e+09  ...             1.871980e+09     7.374382e+10
# 3  1.195070e+09  ...             1.905000e+07     1.504696e+10
# 4  1.424940e+10  ...             2.694648e+11     1.012949e+12
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 1          5.582920e+09          3.810000e+08   9.880600e+08     1.180592e+10
# 2          6.908038e+10          1.978660e+09   3.310128e+10     4.663440e+09
# 3          7.237730e+09          1.905000e+07   3.512820e+09     7.809230e+09
# 4          9.491967e+11          2.176678e+11   1.396086e+11     6.375273e+10
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0             Investments                    3835.0
# 1             Investments                   73157.0
# 2             Investments                   14864.0
# 3             Investments                   10321.0
# 4             Investments                   19248.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                   380471.81  4072324
# 1                  2801746.25  4072324
# 2                  1227269.00  4072324
# 3                   234624.50  4072324
# 4                   130601.75  4072324
#
# [5 rows x 24 columns]

# %%
# Rename features
investments = investments.rename(columns={'incorporated_country': 'Countries',
                                          'Primary activity': 'Primary_activity',
                                          'Primary sector': 'Primary_sector'})

# Drop unneeded columns
investments = investments.drop(
    ['Third_party_verification', 'Scope_3_emissions_type'], axis=1, errors='ignore')

investments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                905 non-null    object
#  1   account_id                  905 non-null    int64
#  2   Year                        905 non-null    int64
#  3   Countries                   905 non-null    object
#  4   Primary_activity            905 non-null    object
#  5   Primary_sector              905 non-null    object
#  6   Market_Cap_USD              810 non-null    float64
#  7   Revenue_USD                 824 non-null    float64
#  8   ebitda_USD                  824 non-null    float64
#  9   grossProfit_USD             824 non-null    float64
#  10  netIncome_USD               824 non-null    float64
#  11  cashAndCashEquivalents_USD  824 non-null    float64
#  12  shortTermInvestments_USD    824 non-null    float64
#  13  longTermInvestments_USD     824 non-null    float64
#  14  totalAssets_USD             824 non-null    float64
#  15  totalLiabilities_USD        824 non-null    float64
#  16  totalInvestments_USD        824 non-null    float64
#  17  totalDebt_USD               824 non-null    float64
#  18  totalEquity_USD             824 non-null    float64
#  19  Scope_3_emissions_amount    905 non-null    float64
#  20  scope_1_2_emissions_amount  904 non-null    float64
#  21  Year_sq                     905 non-null    int64
# dtypes: float64(15), int64(3), object(4)
# memory usage: 155.7+ KB

# %%
# Looking at missing data
print(investments.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                10.5
# cashAndCashEquivalents_USD     9.0
# totalLiabilities_USD           9.0
# totalEquity_USD                9.0
# totalDebt_USD                  9.0
# Revenue_USD                    9.0
# ebitda_USD                     9.0
# grossProfit_USD                9.0
# netIncome_USD                  9.0
# totalInvestments_USD           9.0
# shortTermInvestments_USD       9.0
# longTermInvestments_USD        9.0
# totalAssets_USD                9.0
# scope_1_2_emissions_amount     0.1
# Scope_3_emissions_amount       0.0
# account_name                   0.0
# account_id                     0.0
# Primary_sector                 0.0
# Primary_activity               0.0
# Countries                      0.0
# Year                           0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# ## Investments PCA Feature Engineering
#
# - Select numeric columns from `investments` (exclude IDs, names, categories, raw emissions).
# - Apply signed log transform for normalization.
# - Drop rows with missing data; keep valid indices.
# - Standardize features and fit PCA, retaining all components.
# - Create DataFrame of PCs (`PC1`, `PC2`, ...) and merge with original data for valid rows.
# - Visualize explained variance (scree and cumulative plots).
# - Print cumulative variance explained for each PC.
#
# **Output:**
# `investments_with_pcs` contains original data plus principal components for valid rows.

# %%
# --- STEP 1: Select appropriate columns for PCA ---
exclude_cols = [
    "account_id", "Year", "Year_sq",
    "account_name", "Countries", "Primary_activity", "Primary_sector"
]
numeric_cols = [
    col for col in investments.columns
    if col not in exclude_cols and pd.api.types.is_numeric_dtype(investments[col])
    and col != "Scope_3_emissions_amount"
]
X = investments[numeric_cols].copy()

# --- STEP 2: Apply sign-log transformation ---
def sign_log_transform(x):
    return np.sign(x) * np.log1p(np.abs(x))
X_transformed = X.apply(sign_log_transform)

# --- STEP 3: Drop rows with missing values (keep track of indices) ---
X_dropped = X_transformed.dropna()
pca_indices = X_dropped.index

# --- STEP 4: Standardize the data ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_dropped)

# --- STEP 5: Fit PCA ---
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# --- STEP 6: Create a DataFrame for PCs, index matches original ---
num_pcs = X_pca.shape[1]
pc_columns = [f"PC{i+1}" for i in range(num_pcs)]
pcs_df = pd.DataFrame(X_pca, columns=pc_columns, index=pca_indices)

# --- STEP 7: Append PCs back to the original DataFrame (only for valid rows) ---
investments_with_pcs = investments.copy()
for col in pc_columns:
    investments_with_pcs[col] = np.nan  # initialize with NaN

investments_with_pcs.loc[pcs_df.index, pc_columns] = pcs_df

# --- Plots ---
explained_var_ratio = pca.explained_variance_ratio_

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_var_ratio) + 1), explained_var_ratio, marker='o')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(
    range(1, len(explained_var_ratio) + 1),
    np.cumsum(explained_var_ratio),
    marker='o',
    color='orange'
)
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# --- Print cumulative variance explained for each PC ---
cumulative_var = np.cumsum(explained_var_ratio)
print("Cumulative variance explained by each additional principal component:")
for i, var in enumerate(cumulative_var, start=1):
    print(f"  PC{i}: {var:.4f}")

# --- END ---
# investments_with_pcs now contains the principal components for valid rows.
# Out:
# Cumulative variance explained by each additional principal component:
#   PC1: 0.3199
#   PC2: 0.4536
#   PC3: 0.5493
#   PC4: 0.6265
#   PC5: 0.6974
#   PC6: 0.7599
#   PC7: 0.8151
#   PC8: 0.8558
#   PC9: 0.8941
#   PC10: 0.9257
#   PC11: 0.9525
#   PC12: 0.9751
#   PC13: 0.9889
#   PC14: 1.0000

# %% [markdown]
# Ten pc's explains >90% of the variance in the data, seven pc's explain >80% of the variance and 4 pc's is at the bottom of the "elbow" with much less significant return for each increase in number of pc's.<br>
# I'll investigate 10, 7 and 4 pc's performance on HLM models.

# %% [markdown]
# ## Investments PCA Features & Train/Test Split
#
# - Select numeric columns (excluding IDs, names, year, categories, raw emissions).
# - Apply signed log transform for normalization.
# - Drop rows with missing values; keep account_id and Year for valid indices.
# - Standardize features, fit PCA for **10** (`PC10_*`), **7** (`PC7_*`), and **4** (`PC4_*`) components.
# - Append all principal components to the original DataFrame.
# - Add signed log-transformed target variable.
# - Optionally, rename columns for consistency.
# - **Split data:**
#   - `train_df`: years 2018–2022
#   - `test_df`: year 2023
#   - Test set includes only companies present in training.
#
# **Output:**
# `investments_pca` has original data plus PC10, PC7, PC4 features and transformed target.
# `train_df`, `test_df` are ready for modeling/evaluation.

# %%
# --- Prepare Data ---
exclude_cols = [
    "account_id", "Year", "Year_sq",
    "account_name", "Countries", "Primary_activity", "Primary_sector"
]
numeric_cols = [
    col for col in investments.columns
    if col not in exclude_cols and pd.api.types.is_numeric_dtype(investments[col])
    and col != "Scope_3_emissions_amount"
]
X = investments[numeric_cols].copy()

def sign_log_transform(x):
    return np.sign(x) * np.log1p(np.abs(x))
X_transformed = X.apply(sign_log_transform)
pca_data = X_transformed.dropna().copy()
pca_data["account_id"] = investments.loc[pca_data.index, "account_id"]
pca_data["Year"] = investments.loc[pca_data.index, "Year"]

X_pca_input = pca_data.drop(columns=["account_id", "Year"])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_pca_input)

# --- PCA for 10 components ---
pca10 = PCA(n_components=10)
pcs10 = pca10.fit_transform(X_scaled)
pcs10_df = pd.DataFrame(pcs10, columns=[f"PC10_{i+1}" for i in range(10)], index=pca_data.index)

# --- PCA for 7 components ---
pca7 = PCA(n_components=7)
pcs7 = pca7.fit_transform(X_scaled)
pcs7_df = pd.DataFrame(pcs7, columns=[f"PC7_{i+1}" for i in range(7)], index=pca_data.index)

# --- PCA for 4 components ---
pca4 = PCA(n_components=4)
pcs4 = pca4.fit_transform(X_scaled)
pcs4_df = pd.DataFrame(pcs4, columns=[f"PC4_{i+1}" for i in range(4)], index=pca_data.index)

# --- Merge all PC features to original DataFrame ---
investments_pca = investments.copy()
investments_pca = investments_pca.join(pcs10_df)
investments_pca = investments_pca.join(pcs7_df)
investments_pca = investments_pca.join(pcs4_df)

# --- Add transformed target and optionally other features ---
investments_pca['slog_Scope_3_emissions_amount'] = sign_log_transform(investments_pca['Scope_3_emissions_amount'])

# Optional: Rename columns for consistency
investments_pca = investments_pca.rename(columns={
    'incorporated_country': 'Countries',
    'Primary activity': 'Primary_activity',
    'Primary sector': 'Primary_sector'
})

# --- Split train/test by company and year ---
train_df = investments_pca[investments_pca['Year'].between(2018, 2022)].copy()
test_df  = investments_pca[investments_pca['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (683, 44)
# Test shape: (159, 44)

# %%
print(train_df.info())
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 683 entries, 0 to 682
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   account_name                   683 non-null    object
#  1   account_id                     683 non-null    int64
#  2   Year                           683 non-null    int64
#  3   Countries                      683 non-null    object
#  4   Primary_activity               683 non-null    object
#  5   Primary_sector                 683 non-null    object
#  6   Market_Cap_USD                 603 non-null    float64
#  7   Revenue_USD                    622 non-null    float64
#  8   ebitda_USD                     622 non-null    float64
#  9   grossProfit_USD                622 non-null    float64
#  10  netIncome_USD                  622 non-null    float64
#  11  cashAndCashEquivalents_USD     622 non-null    float64
#  12  shortTermInvestments_USD       622 non-null    float64
#  13  longTermInvestments_USD        622 non-null    float64
#  14  totalAssets_USD                622 non-null    float64
#  15  totalLiabilities_USD           622 non-null    float64
#  16  totalInvestments_USD           622 non-null    float64
#  17  totalDebt_USD                  622 non-null    float64
#  18  totalEquity_USD                622 non-null    float64
#  19  Scope_3_emissions_amount       683 non-null    float64
#  20  scope_1_2_emissions_amount     683 non-null    float64
#  21  Year_sq                        683 non-null    int64
#  22  PC10_1                         602 non-null    float64
#  23  PC10_2                         602 non-null    float64
#  24  PC10_3                         602 non-null    float64
#  25  PC10_4                         602 non-null    float64
#  26  PC10_5                         602 non-null    float64
#  27  PC10_6                         602 non-null    float64
#  28  PC10_7                         602 non-null    float64
#  29  PC10_8                         602 non-null    float64
#  30  PC10_9                         602 non-null    float64
#  31  PC10_10                        602 non-null    float64
#  32  PC7_1                          602 non-null    float64
#  33  PC7_2                          602 non-null    float64
#  34  PC7_3                          602 non-null    float64
#  35  PC7_4                          602 non-null    float64
#  36  PC7_5                          602 non-null    float64
#  37  PC7_6                          602 non-null    float64
#  38  PC7_7                          602 non-null    float64
#  39  PC4_1                          602 non-null    float64
#  40  PC4_2                          602 non-null    float64
#  41  PC4_3                          602 non-null    float64
#  42  PC4_4                          602 non-null    float64
#  43  slog_Scope_3_emissions_amount  683 non-null    float64
# dtypes: float64(37), int64(3), object(4)
# memory usage: 240.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 683 to 903
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   account_name                   159 non-null    object
#  1   account_id                     159 non-null    int64
#  2   Year                           159 non-null    int64
#  3   Countries                      159 non-null    object
#  4   Primary_activity               159 non-null    object
#  5   Primary_sector                 159 non-null    object
#  6   Market_Cap_USD                 147 non-null    float64
#  7   Revenue_USD                    144 non-null    float64
#  8   ebitda_USD                     144 non-null    float64
#  9   grossProfit_USD                144 non-null    float64
#  10  netIncome_USD                  144 non-null    float64
#  11  cashAndCashEquivalents_USD     144 non-null    float64
#  12  shortTermInvestments_USD       144 non-null    float64
#  13  longTermInvestments_USD        144 non-null    float64
#  14  totalAssets_USD                144 non-null    float64
#  15  totalLiabilities_USD           144 non-null    float64
#  16  totalInvestments_USD           144 non-null    float64
#  17  totalDebt_USD                  144 non-null    float64
#  18  totalEquity_USD                144 non-null    float64
#  19  Scope_3_emissions_amount       159 non-null    float64
#  20  scope_1_2_emissions_amount     159 non-null    float64
#  21  Year_sq                        159 non-null    int64
#  22  PC10_1                         142 non-null    float64
#  23  PC10_2                         142 non-null    float64
#  24  PC10_3                         142 non-null    float64
#  25  PC10_4                         142 non-null    float64
#  26  PC10_5                         142 non-null    float64
#  27  PC10_6                         142 non-null    float64
#  28  PC10_7                         142 non-null    float64
#  29  PC10_8                         142 non-null    float64
#  30  PC10_9                         142 non-null    float64
#  31  PC10_10                        142 non-null    float64
#  32  PC7_1                          142 non-null    float64
#  33  PC7_2                          142 non-null    float64
#  34  PC7_3                          142 non-null    float64
#  35  PC7_4                          142 non-null    float64
#  36  PC7_5                          142 non-null    float64
#  37  PC7_6                          142 non-null    float64
#  38  PC7_7                          142 non-null    float64
#  39  PC4_1                          142 non-null    float64
#  40  PC4_2                          142 non-null    float64
#  41  PC4_3                          142 non-null    float64
#  42  PC4_4                          142 non-null    float64
#  43  slog_Scope_3_emissions_amount  159 non-null    float64
# dtypes: float64(37), int64(3), object(4)
# memory usage: 55.9+ KB
# None

# %% [markdown]
# ## Investments HLM Model with PC10 Features (Train/Test Split)
#
# - Uses `train_df` and `test_df` from investments PCA workflow.
# - Filters for required features: PC10 components, target, and categorical columns.
# - Ensures all categorical levels in test are present in train.
# - Fits hierarchical linear mixed-effects model with PC10 features, country, activity, and year.
# - Evaluates model performance on the test set and prints metrics.
# - Visualizes distributions and top feature coefficients.
#
# **Output:**
# Performance metrics and visualizations for HLM using PC10 principal components.

# %%
# --- HLM Model for investments using PC10 features and train/test split ---

# Use train_df and test_df created from investments_pca
feature_cols_PC10 = [f'PC10_{i+1}' for i in range(10)]
target_col_PC10 = 'slog_Scope_3_emissions_amount'
cat_cols_PC10 = ['Countries', 'Year', 'account_id', 'Primary_activity']
all_model_vars_PC10 = feature_cols_PC10 + [target_col_PC10] + cat_cols_PC10

# Filter for required columns only
train_df_PC10 = train_df.dropna(subset=all_model_vars_PC10).copy()
test_df_PC10 = test_df.dropna(subset=all_model_vars_PC10).copy()

# Ensure all categorical levels in test are present in train
for cat_col in ['Countries', 'Primary_activity']:
    train_cats = set(train_df_PC10[cat_col].unique())
    n_before = len(test_df_PC10)
    test_df_PC10 = test_df_PC10[test_df_PC10[cat_col].isin(train_cats)]
    n_after = len(test_df_PC10)
    if n_after < n_before:
        print(f"Warning: Dropped {n_before - n_after} test rows with unseen {cat_col} categories.")

if test_df_PC10.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # Model formula (only PC10 features as predictors)
    fixed_effects = (
        ' + '.join(feature_cols_PC10) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_PC10} ~ {fixed_effects}'

    # Fit the mixed-effects model
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_PC10, groups=train_df_PC10['account_id'])
        mdf_PC10 = md.fit(reml=False)
    print(mdf_PC10.summary())

    # Calculate conditional and marginal R²
    var_fixed = np.var(mdf_PC10.fittedvalues)
    var_resid = mdf_PC10.scale
    var_random = mdf_PC10.cov_re.iloc[0, 0] if mdf_PC10.cov_re.shape[0] > 0 else 0.0
    var_random_total = var_random

    r2_marginal = var_fixed / (var_fixed + var_random_total + var_resid)
    r2_conditional = (var_fixed + var_random_total) / (var_fixed + var_random_total + var_resid)

    print(f"Marginal R² (fixed only):      {r2_marginal:.4f}")
    print(f"Conditional R² (fixed+random): {r2_conditional:.4f}")

    # Predict on test set
    test_df_PC10['predicted_log'] = mdf_PC10.predict(test_df_PC10)
    test_df_PC10['predicted'] = np.sign(test_df_PC10['predicted_log']) * (np.expm1(np.abs(test_df_PC10['predicted_log'])))

    # Metrics
    y_true_log = test_df_PC10[target_col_PC10]
    y_pred_log = test_df_PC10['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_PC10['predicted']

    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)

    metrics_text = (
        f"Conditional R²:   {r2_conditional*100:.2f}%\n"
        f"Marginal R²:      {r2_marginal*100:.2f}%\n"
        f"MAPE:             {mape_orig:.2f}%\n"
        f"MAPE(log):        {mape_log:.2f}%\n"
        f"MAE(log):         {mae_log:.2f}\n"
        f"RMSLE:            {rmsle:.2f}\n"
        f"RMSE:             {rmse_orig:.2f}\n"
        f"MAE:              {mae_orig:.2f}"
    )

    print("\ninvestments HLM with PC10 Fixed Effects: Test Set Performance Metrics:")
    print(metrics_text)

    # Feature coefficients
    coef_df = pd.DataFrame({
        'coef': mdf_PC10.params,
        'pvalue': mdf_PC10.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))
    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # Visualization
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("investments HLM (PC10 Fixed Effects): Signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()
    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("investments HLM (PC10 Fixed Effects): Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()
    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    plt.tight_layout()
    plt.show()
    valid_hist_mask = np.isfinite(y_true) & np.isfinite(y_pred) & (y_true > -1) & (y_pred > -1)
    y_true_hist = y_true[valid_hist_mask]
    y_pred_hist = y_pred[valid_hist_mask]
    if len(y_true_hist) > 0 and len(y_pred_hist) > 0:
        min_val = min(y_true_hist.min(), y_pred_hist.min())
        max_val = max(y_true_hist.max(), y_pred_hist.max())
        if (min_val + 1) > 0 and (max_val + 1) > 0:
            log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)
            plt.figure(figsize=(8, 5))
            sns.histplot(y_true_hist, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
            sns.histplot(y_pred_hist, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="HLM Model Predicted")
            plt.xscale("log")
            plt.title("investments HLM (PC10 Fixed Effects): Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
            plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
            plt.ylabel("Density")
            plt.legend()
            plt.tight_layout()
            plt.show()
        else:
            print("Error: min_val or max_val invalid for log scaling.")
    else:
        print("Error: No valid y_true/y_pred values for histogram.")

    # RETURN METRICS FOR SUMMARY TABLE
    PC10_model_metrics = {
        "Model": "HLM PC10",
        "Conditional_R2": r2_conditional,
        "Marginal_R2": r2_marginal,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "MAE_log": mae_log,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "# Obs (train)": len(train_df_PC10),
        "# Obs (test)": len(test_df_PC10),
        "# Obs (train/test)": f"{len(train_df_PC10)}/{len(test_df_PC10)}"
    }
# Out:
# Warning: Dropped 2 test rows with unseen Countries categories.
# Warning: Dropped 3 test rows with unseen Primary_activity categories.
#                                          Mixed Linear Model Regression Results
# =======================================================================================================================
# Model:                            MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                 602                   Method:                           ML
# No. Groups:                       214                   Scale:                            1.0415
# Min. group size:                  1                     Log-Likelihood:                   -1073.3296
# Max. group size:                  5                     Converged:                        Yes
# Mean group size:                  2.8
# -----------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                  68.152   74.334  0.917 0.359 -77.541 213.844
# C(Countries)[T.Belgium]                                                     3.775    1.617  2.334 0.020   0.604   6.945
# C(Countries)[T.Brazil]                                                      1.282    2.022  0.634 0.526  -2.681   5.246
# C(Countries)[T.Canada]                                                      3.257    1.102  2.956 0.003   1.097   5.416
# C(Countries)[T.China]                                                       2.695    1.258  2.143 0.032   0.230   5.160
# C(Countries)[T.Denmark]                                                     5.025    1.474  3.408 0.001   2.136   7.915
# C(Countries)[T.Finland]                                                     1.814    1.958  0.927 0.354  -2.023   5.652
# C(Countries)[T.France]                                                      2.773    1.131  2.451 0.014   0.556   4.991
# C(Countries)[T.Germany]                                                     0.809    1.292  0.626 0.531  -1.724   3.341
# C(Countries)[T.Ireland]                                                     3.759    2.104  1.786 0.074  -0.365   7.884
# C(Countries)[T.Italy]                                                       4.517    1.436  3.146 0.002   1.703   7.331
# C(Countries)[T.Japan]                                                       2.447    0.943  2.595 0.009   0.599   4.294
# C(Countries)[T.Mexico]                                                      4.486    1.601  2.802 0.005   1.349   7.624
# C(Countries)[T.Netherlands]                                                 4.570    1.122  4.075 0.000   2.372   6.769
# C(Countries)[T.New Zealand]                                                -2.329    1.800 -1.294 0.196  -5.857   1.199
# C(Countries)[T.Norway]                                                      4.525    1.241  3.646 0.000   2.092   6.958
# C(Countries)[T.Portugal]                                                    8.571    2.785  3.078 0.002   3.112  14.029
# C(Countries)[T.Singapore]                                                   3.900    2.133  1.828 0.068  -0.281   8.081
# C(Countries)[T.South Africa]                                                2.955    1.294  2.284 0.022   0.419   5.491
# C(Countries)[T.South Korea]                                                 1.358    1.037  1.310 0.190  -0.675   3.390
# C(Countries)[T.Spain]                                                       1.335    1.081  1.235 0.217  -0.784   3.455
# C(Countries)[T.Sweden]                                                     -1.223    1.983 -0.617 0.537  -5.109   2.664
# C(Countries)[T.Switzerland]                                                -0.162    1.158 -0.140 0.889  -2.433   2.108
# C(Countries)[T.Thailand]                                                    4.146    2.091  1.982 0.047   0.047   8.245
# C(Countries)[T.USA]                                                         2.354    0.958  2.457 0.014   0.476   4.232
# C(Countries)[T.United Kingdom]                                              2.115    1.082  1.955 0.051  -0.005   4.235
# C(Primary_activity)[T.Agriculture, construction & mining machinery]        -0.834    3.195 -0.261 0.794  -7.096   5.427
# C(Primary_activity)[T.Alcoholic beverages]                                 -2.671    2.576 -1.037 0.300  -7.720   2.378
# C(Primary_activity)[T.Animal processing]                                    0.493    2.842  0.173 0.862  -5.078   6.064
# C(Primary_activity)[T.Apparel & footwear design]                            0.270    2.720  0.099 0.921  -5.060   5.600
# C(Primary_activity)[T.Apparel stores]                                      -0.558    2.765 -0.202 0.840  -5.977   4.861
# C(Primary_activity)[T.Aquaculture]                                         -4.185    2.634 -1.589 0.112  -9.347   0.978
# C(Primary_activity)[T.Asset managers]                                      -0.460    2.392 -0.192 0.847  -5.148   4.227
# C(Primary_activity)[T.Automobiles]                                         -3.278    2.835 -1.156 0.247  -8.835   2.278
# C(Primary_activity)[T.Baked goods & cereals]                                1.953    2.698  0.724 0.469  -3.334   7.240
# C(Primary_activity)[T.Banks]                                               -0.996    2.087 -0.477 0.633  -5.086   3.094
# C(Primary_activity)[T.Biotechnology]                                       -2.266    2.319 -0.977 0.328  -6.812   2.279
# C(Primary_activity)[T.Building sub-contractors]                             0.963    2.570  0.375 0.708  -4.073   6.000
# C(Primary_activity)[T.CCGT generation]                                     -0.307    2.400 -0.128 0.898  -5.011   4.397
# C(Primary_activity)[T.Commercial services]                                 -1.308    2.668 -0.490 0.624  -6.536   3.921
# C(Primary_activity)[T.Communications equipment]                            -0.551    2.719 -0.203 0.840  -5.880   4.779
# C(Primary_activity)[T.Computer hardware]                                    1.637    2.457  0.666 0.505  -3.179   6.453
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  0.463    2.468  0.187 0.851  -4.374   5.300
# C(Primary_activity)[T.Department stores]                                   -6.823    2.654 -2.570 0.010 -12.026  -1.621
# C(Primary_activity)[T.Discretionary delivery retail]                       -1.536    2.853 -0.538 0.590  -7.128   4.056
# C(Primary_activity)[T.Electrical equipment]                                -1.471    2.229 -0.660 0.509  -5.839   2.896
# C(Primary_activity)[T.Electricity networks]                                -2.887    2.947 -0.980 0.327  -8.664   2.889
# C(Primary_activity)[T.Electronic components]                               -1.920    2.201 -0.872 0.383  -6.234   2.395
# C(Primary_activity)[T.Electronic equipment]                                -3.471    2.206 -1.573 0.116  -7.795   0.853
# C(Primary_activity)[T.Energy infrastructure construction]                  -1.384    2.790 -0.496 0.620  -6.853   4.085
# C(Primary_activity)[T.Engineering services]                                 0.313    2.927  0.107 0.915  -5.423   6.050
# C(Primary_activity)[T.Engines & motors]                                    -1.296    2.881 -0.450 0.653  -6.943   4.352
# C(Primary_activity)[T.Fabricated metal components]                         -1.292    2.271 -0.569 0.569  -5.743   3.160
# C(Primary_activity)[T.Fast food]                                           -0.310    2.813 -0.110 0.912  -5.823   5.204
# C(Primary_activity)[T.Food & beverage amenities]                           -2.281    2.815 -0.810 0.418  -7.798   3.237
# C(Primary_activity)[T.Food & beverage wholesale]                           -2.961    2.799 -1.058 0.290  -8.446   2.524
# C(Primary_activity)[T.Gas utilities]                                       -1.442    2.430 -0.593 0.553  -6.205   3.322
# C(Primary_activity)[T.Glass products]                                      -1.097    2.764 -0.397 0.691  -6.515   4.320
# C(Primary_activity)[T.Grain & corn milling]                                 0.017    2.895  0.006 0.995  -5.658   5.691
# C(Primary_activity)[T.Health care services]                                -5.458    2.815 -1.939 0.053 -10.976   0.060
# C(Primary_activity)[T.Industrial machinery]                                -4.329    2.670 -1.621 0.105  -9.561   0.904
# C(Primary_activity)[T.Inorganic base chemicals]                             1.904    2.353  0.809 0.418  -2.708   6.517
# C(Primary_activity)[T.Insurance]                                            0.433    2.112  0.205 0.838  -3.707   4.573
# C(Primary_activity)[T.Intermodal transport]                                -2.666    2.688 -0.992 0.321  -7.934   2.603
# C(Primary_activity)[T.Iron & steel]                                         4.042    2.834  1.426 0.154  -1.512   9.597
# C(Primary_activity)[T.Logging]                                              0.243    2.686  0.090 0.928  -5.023   5.508
# C(Primary_activity)[T.Logistics - 3rd party]                               -4.418    3.001 -1.472 0.141 -10.299   1.463
# C(Primary_activity)[T.Logistics - transport]                               -5.881    2.893 -2.033 0.042 -11.551  -0.211
# C(Primary_activity)[T.Marine freight]                                       2.038    2.753  0.740 0.459  -3.357   7.433
# C(Primary_activity)[T.Marketing]                                            0.494    2.227  0.222 0.824  -3.870   4.858
# C(Primary_activity)[T.Medical equipment]                                   -2.868    2.422 -1.184 0.236  -7.616   1.880
# C(Primary_activity)[T.Metal containers & packaging]                         1.143    2.694  0.424 0.671  -4.137   6.424
# C(Primary_activity)[T.Nitrogenous fertilizers]                              2.290    2.909  0.787 0.431  -3.411   7.992
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                          1.034    2.728  0.379 0.705  -4.313   6.380
# C(Primary_activity)[T.Non-residential building construction]               -1.507    2.514 -0.600 0.549  -6.434   3.420
# C(Primary_activity)[T.Oil & gas marketing & retailing]                     -8.657    3.362 -2.575 0.010 -15.246  -2.067
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       -0.221    2.343 -0.094 0.925  -4.814   4.372
# C(Primary_activity)[T.Other base chemicals]                                 0.401    2.263  0.177 0.859  -4.035   4.837
# C(Primary_activity)[T.Other containers & packaging]                        -0.246    2.780 -0.088 0.930  -5.695   5.204
# C(Primary_activity)[T.Other food processing]                               -1.333    2.360 -0.565 0.572  -5.958   3.293
# C(Primary_activity)[T.Other professional services]                         -3.407    2.165 -1.574 0.116  -7.651   0.836
# C(Primary_activity)[T.Other renewable energy equipment]                    -4.858    3.002 -1.618 0.106 -10.741   1.026
# C(Primary_activity)[T.Other renewable generation]                         -10.358    3.884 -2.667 0.008 -17.971  -2.745
# C(Primary_activity)[T.Paper products]                                      -0.946    2.592 -0.365 0.715  -6.025   4.134
# C(Primary_activity)[T.Passenger airlines]                                  -0.362    2.305 -0.157 0.875  -4.880   4.156
# C(Primary_activity)[T.Passenger rail]                                      -0.301    2.828 -0.106 0.915  -5.844   5.242
# C(Primary_activity)[T.Personal care & household products]                  -0.574    2.164 -0.265 0.791  -4.815   3.668
# C(Primary_activity)[T.Pharmaceuticals]                                     -3.016    2.241 -1.346 0.178  -7.408   1.376
# C(Primary_activity)[T.Precious metals & minerals mining]                   -0.694    2.360 -0.294 0.769  -5.320   3.933
# C(Primary_activity)[T.Print publishing]                                    -2.639    2.370 -1.114 0.265  -7.285   2.006
# C(Primary_activity)[T.Printing services]                                   -2.804    2.692 -1.042 0.298  -8.079   2.472
# C(Primary_activity)[T.REIT]                                                -2.090    2.286 -0.914 0.361  -6.571   2.391
# C(Primary_activity)[T.Residential building construction]                   -2.456    2.288 -1.073 0.283  -6.941   2.029
# C(Primary_activity)[T.Rubber products]                                     -0.519    2.349 -0.221 0.825  -5.123   4.086
# C(Primary_activity)[T.Semiconductors]                                       1.232    2.838  0.434 0.664  -4.332   6.795
# C(Primary_activity)[T.Software]                                            -3.347    2.656 -1.260 0.208  -8.552   1.858
# C(Primary_activity)[T.Solar energy equipment]                              -1.423    2.699 -0.527 0.598  -6.714   3.868
# C(Primary_activity)[T.Specialist retail]                                   -2.012    2.586 -0.778 0.437  -7.081   3.057
# C(Primary_activity)[T.Specialty chemicals]                                 -0.300    2.349 -0.128 0.898  -4.904   4.304
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     -0.493    2.159 -0.228 0.819  -4.724   3.738
# C(Primary_activity)[T.Telecommunications services]                          0.899    2.150  0.418 0.676  -3.314   5.112
# C(Primary_activity)[T.Textiles]                                            -0.641    2.992 -0.214 0.830  -6.505   5.223
# C(Primary_activity)[T.Tobacco products]                                     2.119    2.320  0.913 0.361  -2.429   6.666
# C(Primary_activity)[T.Transportation infrastructure & other construction]   2.074    2.379  0.872 0.383  -2.589   6.738
# C(Primary_activity)[T.Transportation support services]                      0.503    2.738  0.184 0.854  -4.863   5.868
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]               -4.160    2.366 -1.759 0.079  -8.797   0.476
# C(Primary_activity)[T.Waste management]                                    -3.640    2.757 -1.320 0.187  -9.044   1.764
# PC10_1                                                                      0.244    0.081  3.012 0.003   0.085   0.403
# PC10_2                                                                     -0.099    0.049 -2.019 0.043  -0.195  -0.003
# PC10_3                                                                     -0.287    0.098 -2.939 0.003  -0.478  -0.096
# PC10_4                                                                      0.155    0.109  1.424 0.154  -0.058   0.368
# PC10_5                                                                      0.283    0.109  2.605 0.009   0.070   0.496
# PC10_6                                                                      0.177    0.114  1.554 0.120  -0.046   0.401
# PC10_7                                                                      0.211    0.122  1.736 0.083  -0.027   0.449
# PC10_8                                                                     -0.091    0.104 -0.869 0.385  -0.295   0.114
# PC10_9                                                                     -0.028    0.107 -0.266 0.791  -0.237   0.181
# PC10_10                                                                     0.105    0.115  0.914 0.361  -0.120   0.330
# Year                                                                       -0.029    0.037 -0.794 0.427  -0.101   0.043
# Group Var                                                                   2.576    0.397
# =======================================================================================================================
#
# Marginal R² (fixed only):      0.6427
# Conditional R² (fixed+random): 0.8971
#
# investments HLM with PC10 Fixed Effects: Test Set Performance Metrics:
# Conditional R²:   89.71%
# Marginal R²:      64.27%
# MAPE:             2044.88%
# MAPE(log):        18.09%
# MAE(log):         1.68
# RMSLE:            2.22
# RMSE:             1060855.49
# MAE:              385727.09
#
# Top Influential Features (by p-value):
#                                  coef        pvalue
# Group Var                    2.473791  1.998853e-10
# C(Countries)[T.Netherlands]  4.570189  4.608029e-05
# C(Countries)[T.Norway]       4.525169  2.668558e-04
# C(Countries)[T.Denmark]      5.025477  6.532484e-04
# C(Countries)[T.Italy]        4.516886  1.653728e-03
# C(Countries)[T.Portugal]     8.570645  2.087081e-03
# PC10_1                       0.244381  2.594349e-03
# C(Countries)[T.Canada]       3.256554  3.120461e-03
# PC10_3                      -0.286909  3.288437e-03
# C(Countries)[T.Mexico]       4.486263  5.072641e-03
#
# All feature coefficients sorted by absolute value:
#                                                          coef    pvalue
# C(Primary_activity)[T.Other renewable generation]  -10.357689  0.007661
# C(Primary_activity)[T.Oil & gas marketing & ret...  -8.656945  0.010026
# C(Countries)[T.Portugal]                             8.570645  0.002087
# C(Primary_activity)[T.Department stores]            -6.823186  0.010155
# C(Primary_activity)[T.Logistics - transport]        -5.880932  0.042053
# ...                                                       ...       ...
# PC10_2                                              -0.099143  0.043493
# PC10_8                                              -0.090628  0.384864
# Year                                                -0.029254  0.426955
# PC10_9                                              -0.028307  0.790597
# C(Primary_activity)[T.Grain & corn milling]          0.016520  0.995447
#
# [118 rows x 2 columns]

# %% [markdown]
# ## Investments HLM Model with PC7 Features (Train/Test Split)
#
# - Uses `train_df` and `test_df` from investments PCA workflow.
# - Filters for required features: PC7 components, target, and categorical columns.
# - Ensures all categorical levels in test are present in train.
# - Fits hierarchical linear mixed-effects model with PC7 features, country, activity, and year.
# - Evaluates model performance on the test set and prints metrics.
# - Visualizes distributions and top feature coefficients.
#
# **Output:**
# Performance metrics and visualizations for HLM using PC7 principal components.

# %%
# --- HLM Model for investments using PC7 features and train/test split ---

feature_cols_PC7 = [f'PC7_{i+1}' for i in range(7)]
target_col_PC7 = 'slog_Scope_3_emissions_amount'
cat_cols_PC7 = ['Countries', 'Year', 'account_id', 'Primary_activity']
all_model_vars_PC7 = feature_cols_PC7 + [target_col_PC7] + cat_cols_PC7

# Filter for required columns only
train_df_PC7 = train_df.dropna(subset=all_model_vars_PC7).copy()
test_df_PC7 = test_df.dropna(subset=all_model_vars_PC7).copy()

# Ensure all categorical levels in test are present in train
for cat_col in ['Countries', 'Primary_activity']:
    train_cats = set(train_df_PC7[cat_col].unique())
    n_before = len(test_df_PC7)
    test_df_PC7 = test_df_PC7[test_df_PC7[cat_col].isin(train_cats)]
    n_after = len(test_df_PC7)
    if n_after < n_before:
        print(f"Warning: Dropped {n_before - n_after} test rows with unseen {cat_col} categories.")

if test_df_PC7.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # Model formula (only PC7 features as predictors)
    fixed_effects = (
        ' + '.join(feature_cols_PC7) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_PC7} ~ {fixed_effects}'

    # Fit the mixed-effects model
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_PC7, groups=train_df_PC7['account_id'])
        mdf_PC7 = md.fit(reml=False)
    print(mdf_PC7.summary())

    # Calculate conditional and marginal R²
    var_fixed = np.var(mdf_PC7.fittedvalues)
    var_resid = mdf_PC7.scale
    var_random = mdf_PC7.cov_re.iloc[0, 0] if mdf_PC7.cov_re.shape[0] > 0 else 0.0
    var_random_total = var_random

    r2_marginal = var_fixed / (var_fixed + var_random_total + var_resid)
    r2_conditional = (var_fixed + var_random_total) / (var_fixed + var_random_total + var_resid)

    print(f"Marginal R² (fixed only):      {r2_marginal:.4f}")
    print(f"Conditional R² (fixed+random): {r2_conditional:.4f}")

    # Predict on test set
    test_df_PC7['predicted_log'] = mdf_PC7.predict(test_df_PC7)
    test_df_PC7['predicted'] = np.sign(test_df_PC7['predicted_log']) * (np.expm1(np.abs(test_df_PC7['predicted_log'])))

    # Metrics
    y_true_log = test_df_PC7[target_col_PC7]
    y_pred_log = test_df_PC7['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_PC7['predicted']

    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)

    metrics_text = (
        f"Conditional R²:   {r2_conditional*100:.2f}%\n"
        f"Marginal R²:      {r2_marginal*100:.2f}%\n"
        f"MAPE:             {mape_orig:.2f}%\n"
        f"MAPE(log):        {mape_log:.2f}%\n"
        f"MAE(log):         {mae_log:.2f}\n"
        f"RMSLE:            {rmsle:.2f}\n"
        f"RMSE:             {rmse_orig:.2f}\n"
        f"MAE:              {mae_orig:.2f}"
    )

    print("\ninvestments HLM with PC7 Fixed Effects: Test Set Performance Metrics:")
    print(metrics_text)

    # Feature coefficients
    coef_df = pd.DataFrame({
        'coef': mdf_PC7.params,
        'pvalue': mdf_PC7.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))
    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # Visualization
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("investments HLM (PC7 Fixed Effects): Signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()
    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("investments HLM (PC7 Fixed Effects): Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()
    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    plt.tight_layout()
    plt.show()
    valid_hist_mask = np.isfinite(y_true) & np.isfinite(y_pred) & (y_true > -1) & (y_pred > -1)
    y_true_hist = y_true[valid_hist_mask]
    y_pred_hist = y_pred[valid_hist_mask]
    if len(y_true_hist) > 0 and len(y_pred_hist) > 0:
        min_val = min(y_true_hist.min(), y_pred_hist.min())
        max_val = max(y_true_hist.max(), y_pred_hist.max())
        if (min_val + 1) > 0 and (max_val + 1) > 0:
            log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)
            plt.figure(figsize=(8, 5))
            sns.histplot(y_true_hist, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
            sns.histplot(y_pred_hist, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="HLM Model Predicted")
            plt.xscale("log")
            plt.title("investments HLM (PC7 Fixed Effects): Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
            plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
            plt.ylabel("Density")
            plt.legend()
            plt.tight_layout()
            plt.show()
        else:
            print("Error: min_val or max_val invalid for log scaling.")
    else:
        print("Error: No valid y_true/y_pred values for histogram.")

    # RETURN METRICS FOR SUMMARY TABLE
    PC7_model_metrics = {
        "Model": "HLM PC7",
        "Conditional_R2": r2_conditional,
        "Marginal_R2": r2_marginal,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "MAE_log": mae_log,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "# Obs (train)": len(train_df_PC7),
        "# Obs (test)": len(test_df_PC7),
        "# Obs (train/test)": f"{len(train_df_PC7)}/{len(test_df_PC7)}"
    }
# Out:
# Warning: Dropped 2 test rows with unseen Countries categories.
# Warning: Dropped 3 test rows with unseen Primary_activity categories.
#                                         Mixed Linear Model Regression Results
# ======================================================================================================================
# Model:                           MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                602                   Method:                           ML
# No. Groups:                      214                   Scale:                            1.0455
# Min. group size:                 1                     Log-Likelihood:                   -1074.2174
# Max. group size:                 5                     Converged:                        Yes
# Mean group size:                 2.8
# ----------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 62.769   73.636  0.852 0.394 -81.555 207.092
# C(Countries)[T.Belgium]                                                    3.717    1.616  2.300 0.021   0.550   6.884
# C(Countries)[T.Brazil]                                                     1.118    2.016  0.555 0.579  -2.833   5.070
# C(Countries)[T.Canada]                                                     3.212    1.097  2.928 0.003   1.062   5.362
# C(Countries)[T.China]                                                      2.571    1.254  2.051 0.040   0.114   5.028
# C(Countries)[T.Denmark]                                                    4.913    1.472  3.339 0.001   2.029   7.798
# C(Countries)[T.Finland]                                                    1.694    1.956  0.866 0.387  -2.140   5.528
# C(Countries)[T.France]                                                     2.787    1.128  2.471 0.013   0.577   4.997
# C(Countries)[T.Germany]                                                    0.750    1.287  0.583 0.560  -1.772   3.272
# C(Countries)[T.Ireland]                                                    3.761    2.104  1.787 0.074  -0.364   7.885
# C(Countries)[T.Italy]                                                      4.487    1.435  3.127 0.002   1.674   7.300
# C(Countries)[T.Japan]                                                      2.361    0.941  2.508 0.012   0.516   4.205
# C(Countries)[T.Mexico]                                                     4.463    1.601  2.788 0.005   1.326   7.600
# C(Countries)[T.Netherlands]                                                4.462    1.111  4.017 0.000   2.285   6.639
# C(Countries)[T.New Zealand]                                               -2.424    1.795 -1.350 0.177  -5.943   1.095
# C(Countries)[T.Norway]                                                     4.420    1.234  3.581 0.000   2.001   6.839
# C(Countries)[T.Portugal]                                                   8.253    2.752  2.999 0.003   2.860  13.647
# C(Countries)[T.Singapore]                                                  3.852    2.134  1.805 0.071  -0.331   8.035
# C(Countries)[T.South Africa]                                               2.868    1.293  2.218 0.027   0.334   5.403
# C(Countries)[T.South Korea]                                                1.295    1.035  1.252 0.211  -0.733   3.323
# C(Countries)[T.Spain]                                                      1.239    1.079  1.149 0.251  -0.876   3.354
# C(Countries)[T.Sweden]                                                    -1.484    1.973 -0.752 0.452  -5.352   2.384
# C(Countries)[T.Switzerland]                                               -0.149    1.158 -0.128 0.898  -2.419   2.121
# C(Countries)[T.Thailand]                                                   4.039    2.089  1.933 0.053  -0.055   8.132
# C(Countries)[T.USA]                                                        2.398    0.950  2.525 0.012   0.536   4.259
# C(Countries)[T.United Kingdom]                                             2.075    1.081  1.919 0.055  -0.044   4.194
# C(Primary_activity)[T.Agriculture, construction & mining machinery]       -0.556    3.184 -0.175 0.861  -6.796   5.684
# C(Primary_activity)[T.Alcoholic beverages]                                -2.396    2.548 -0.940 0.347  -7.391   2.599
# C(Primary_activity)[T.Animal processing]                                   0.684    2.826  0.242 0.809  -4.854   6.222
# C(Primary_activity)[T.Apparel & footwear design]                           0.457    2.703  0.169 0.866  -4.842   5.755
# C(Primary_activity)[T.Apparel stores]                                     -0.278    2.747 -0.101 0.919  -5.662   5.106
# C(Primary_activity)[T.Aquaculture]                                        -4.026    2.603 -1.547 0.122  -9.128   1.076
# C(Primary_activity)[T.Asset managers]                                     -0.354    2.378 -0.149 0.882  -5.016   4.307
# C(Primary_activity)[T.Automobiles]                                        -3.035    2.823 -1.075 0.282  -8.569   2.499
# C(Primary_activity)[T.Baked goods & cereals]                               2.141    2.674  0.800 0.423  -3.101   7.382
# C(Primary_activity)[T.Banks]                                              -0.919    2.061 -0.446 0.655  -4.958   3.119
# C(Primary_activity)[T.Biotechnology]                                      -2.067    2.306 -0.896 0.370  -6.587   2.454
# C(Primary_activity)[T.Building sub-contractors]                            1.016    2.544  0.399 0.690  -3.969   6.002
# C(Primary_activity)[T.CCGT generation]                                    -0.108    2.368 -0.046 0.964  -4.750   4.534
# C(Primary_activity)[T.Commercial services]                                -1.088    2.657 -0.410 0.682  -6.295   4.119
# C(Primary_activity)[T.Communications equipment]                           -0.453    2.695 -0.168 0.866  -5.735   4.829
# C(Primary_activity)[T.Computer hardware]                                   1.827    2.438  0.749 0.454  -2.952   6.606
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 0.679    2.451  0.277 0.782  -4.125   5.484
# C(Primary_activity)[T.Department stores]                                  -6.644    2.639 -2.518 0.012 -11.816  -1.473
# C(Primary_activity)[T.Discretionary delivery retail]                      -1.319    2.835 -0.465 0.642  -6.876   4.238
# C(Primary_activity)[T.Electrical equipment]                               -1.108    2.207 -0.502 0.616  -5.434   3.218
# C(Primary_activity)[T.Electricity networks]                               -2.740    2.923 -0.937 0.349  -8.469   2.989
# C(Primary_activity)[T.Electronic components]                              -1.748    2.184 -0.800 0.424  -6.029   2.534
# C(Primary_activity)[T.Electronic equipment]                               -3.267    2.190 -1.492 0.136  -7.559   1.025
# C(Primary_activity)[T.Energy infrastructure construction]                 -1.348    2.774 -0.486 0.627  -6.784   4.088
# C(Primary_activity)[T.Engineering services]                                0.435    2.917  0.149 0.882  -5.282   6.151
# C(Primary_activity)[T.Engines & motors]                                   -1.107    2.868 -0.386 0.700  -6.727   4.514
# C(Primary_activity)[T.Fabricated metal components]                        -1.072    2.248 -0.477 0.633  -5.478   3.334
# C(Primary_activity)[T.Fast food]                                          -0.390    2.805 -0.139 0.889  -5.887   5.107
# C(Primary_activity)[T.Food & beverage amenities]                          -2.266    2.816 -0.805 0.421  -7.784   3.253
# C(Primary_activity)[T.Food & beverage wholesale]                          -2.693    2.752 -0.979 0.328  -8.087   2.700
# C(Primary_activity)[T.Gas utilities]                                      -1.244    2.409 -0.516 0.606  -5.966   3.478
# C(Primary_activity)[T.Glass products]                                     -0.858    2.743 -0.313 0.754  -6.234   4.518
# C(Primary_activity)[T.Grain & corn milling]                                0.254    2.864  0.089 0.929  -5.360   5.868
# C(Primary_activity)[T.Health care services]                               -5.299    2.802 -1.891 0.059 -10.792   0.193
# C(Primary_activity)[T.Industrial machinery]                               -4.121    2.649 -1.556 0.120  -9.314   1.071
# C(Primary_activity)[T.Inorganic base chemicals]                            2.123    2.331  0.911 0.362  -2.445   6.690
# C(Primary_activity)[T.Insurance]                                           0.593    2.074  0.286 0.775  -3.473   4.659
# C(Primary_activity)[T.Intermodal transport]                               -2.521    2.670 -0.944 0.345  -7.753   2.712
# C(Primary_activity)[T.Iron & steel]                                        4.290    2.813  1.525 0.127  -1.223   9.804
# C(Primary_activity)[T.Logging]                                             0.416    2.667  0.156 0.876  -4.810   5.643
# C(Primary_activity)[T.Logistics - 3rd party]                              -4.433    2.986 -1.484 0.138 -10.286   1.420
# C(Primary_activity)[T.Logistics - transport]                              -5.786    2.883 -2.007 0.045 -11.436  -0.136
# C(Primary_activity)[T.Marine freight]                                      2.135    2.725  0.783 0.433  -3.206   7.476
# C(Primary_activity)[T.Marketing]                                           0.651    2.212  0.294 0.768  -3.685   4.988
# C(Primary_activity)[T.Medical equipment]                                  -2.633    2.411 -1.092 0.275  -7.360   2.093
# C(Primary_activity)[T.Metal containers & packaging]                        1.314    2.674  0.491 0.623  -3.926   6.554
# C(Primary_activity)[T.Nitrogenous fertilizers]                             2.450    2.889  0.848 0.396  -3.212   8.111
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         1.166    2.702  0.431 0.666  -4.130   6.462
# C(Primary_activity)[T.Non-residential building construction]              -1.308    2.501 -0.523 0.601  -6.209   3.593
# C(Primary_activity)[T.Oil & gas marketing & retailing]                    -8.380    3.336 -2.512 0.012 -14.919  -1.842
# C(Primary_activity)[T.Oil & gas pipelines & storage]                      -0.064    2.326 -0.028 0.978  -4.624   4.495
# C(Primary_activity)[T.Other base chemicals]                                0.640    2.239  0.286 0.775  -3.748   5.028
# C(Primary_activity)[T.Other containers & packaging]                       -0.030    2.758 -0.011 0.991  -5.436   5.375
# C(Primary_activity)[T.Other food processing]                              -1.094    2.334 -0.469 0.639  -5.669   3.481
# C(Primary_activity)[T.Other professional services]                        -3.203    2.149 -1.491 0.136  -7.415   1.008
# C(Primary_activity)[T.Other renewable energy equipment]                   -4.432    2.974 -1.490 0.136 -10.261   1.397
# C(Primary_activity)[T.Other renewable generation]                         -9.836    3.855 -2.552 0.011 -17.392  -2.281
# C(Primary_activity)[T.Paper products]                                     -0.730    2.571 -0.284 0.776  -5.770   4.310
# C(Primary_activity)[T.Passenger airlines]                                 -0.198    2.274 -0.087 0.931  -4.655   4.259
# C(Primary_activity)[T.Passenger rail]                                     -0.011    2.814 -0.004 0.997  -5.526   5.503
# C(Primary_activity)[T.Personal care & household products]                 -0.365    2.148 -0.170 0.865  -4.574   3.844
# C(Primary_activity)[T.Pharmaceuticals]                                    -2.747    2.223 -1.236 0.217  -7.105   1.610
# C(Primary_activity)[T.Precious metals & minerals mining]                  -0.483    2.343 -0.206 0.837  -5.075   4.110
# C(Primary_activity)[T.Print publishing]                                   -2.522    2.356 -1.071 0.284  -7.140   2.096
# C(Primary_activity)[T.Printing services]                                  -2.624    2.677 -0.980 0.327  -7.871   2.622
# C(Primary_activity)[T.REIT]                                               -1.949    2.263 -0.861 0.389  -6.384   2.486
# C(Primary_activity)[T.Residential building construction]                  -2.295    2.275 -1.009 0.313  -6.753   2.164
# C(Primary_activity)[T.Rubber products]                                    -0.334    2.323 -0.144 0.886  -4.887   4.219
# C(Primary_activity)[T.Semiconductors]                                      1.501    2.820  0.532 0.595  -4.026   7.028
# C(Primary_activity)[T.Software]                                           -3.136    2.643 -1.186 0.236  -8.316   2.045
# C(Primary_activity)[T.Solar energy equipment]                             -1.364    2.682 -0.508 0.611  -6.620   3.892
# C(Primary_activity)[T.Specialist retail]                                  -1.791    2.566 -0.698 0.485  -6.820   3.237
# C(Primary_activity)[T.Specialty chemicals]                                -0.126    2.315 -0.055 0.956  -4.665   4.412
# C(Primary_activity)[T.Supermarkets, food & drugstores]                    -0.302    2.137 -0.141 0.888  -4.491   3.887
# C(Primary_activity)[T.Telecommunications services]                         1.104    2.133  0.517 0.605  -3.077   5.285
# C(Primary_activity)[T.Textiles]                                           -0.460    2.963 -0.155 0.877  -6.268   5.348
# C(Primary_activity)[T.Tobacco products]                                    2.223    2.312  0.962 0.336  -2.308   6.755
# C(Primary_activity)[T.Transportation infrastructure & other construction]  2.263    2.363  0.958 0.338  -2.368   6.894
# C(Primary_activity)[T.Transportation support services]                     0.748    2.729  0.274 0.784  -4.600   6.097
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -4.087    2.347 -1.741 0.082  -8.686   0.513
# C(Primary_activity)[T.Waste management]                                   -3.396    2.734 -1.242 0.214  -8.754   1.963
# PC7_1                                                                      0.228    0.070  3.283 0.001   0.092   0.365
# PC7_2                                                                     -0.117    0.047 -2.510 0.012  -0.209  -0.026
# PC7_3                                                                     -0.262    0.095 -2.759 0.006  -0.449  -0.076
# PC7_4                                                                      0.172    0.101  1.708 0.088  -0.025   0.370
# PC7_5                                                                      0.282    0.104  2.702 0.007   0.078   0.487
# PC7_6                                                                      0.156    0.109  1.436 0.151  -0.057   0.370
# PC7_7                                                                      0.195    0.121  1.614 0.107  -0.042   0.431
# Year                                                                      -0.027    0.036 -0.731 0.465  -0.098   0.045
# Group Var                                                                  2.579    0.397
# ======================================================================================================================
#
# Marginal R² (fixed only):      0.6421
# Conditional R² (fixed+random): 0.8968
#
# investments HLM with PC7 Fixed Effects: Test Set Performance Metrics:
# Conditional R²:   89.68%
# Marginal R²:      64.21%
# MAPE:             1995.21%
# MAPE(log):        18.01%
# MAE(log):         1.67
# RMSLE:            2.21
# RMSE:             1048422.49
# MAE:              381085.46
#
# Top Influential Features (by p-value):
#                                  coef        pvalue
# Group Var                    2.466779  2.048334e-10
# C(Countries)[T.Netherlands]  4.461666  5.898869e-05
# C(Countries)[T.Norway]       4.420060  3.425863e-04
# C(Countries)[T.Denmark]      4.913384  8.420425e-04
# PC7_1                        0.228273  1.028106e-03
# C(Countries)[T.Italy]        4.487060  1.768367e-03
# C(Countries)[T.Portugal]     8.253482  2.706982e-03
# C(Countries)[T.Canada]       3.211951  3.407728e-03
# C(Countries)[T.Mexico]       4.462654  5.301954e-03
# PC7_3                       -0.262298  5.798590e-03
#
# All feature coefficients sorted by absolute value:
#                                                         coef    pvalue
# C(Primary_activity)[T.Other renewable generation]  -9.836430  0.010722
# C(Primary_activity)[T.Oil & gas marketing & ret... -8.380408  0.011997
# C(Countries)[T.Portugal]                            8.253482  0.002707
# C(Primary_activity)[T.Department stores]           -6.644289  0.011799
# C(Primary_activity)[T.Logistics - transport]       -5.786291  0.044725
# ...                                                      ...       ...
# C(Primary_activity)[T.CCGT generation]             -0.108080  0.963601
# C(Primary_activity)[T.Oil & gas pipelines & sto... -0.064243  0.977969
# C(Primary_activity)[T.Other containers & packag... -0.030453  0.991191
# Year                                               -0.026659  0.465025
# C(Primary_activity)[T.Passenger rail]              -0.011429  0.996759
#
# [115 rows x 2 columns]

# %% [markdown]
# ## Investments HLM Model with PC4 Features (Train/Test Split)
#
# - Uses `train_df` and `test_df` from investments PCA workflow.
# - Filters for required features: PC4 components, target, and categorical columns.
# - Ensures all categorical levels in test are present in train.
# - Fits hierarchical linear mixed-effects model with PC4 features, country, activity, and year.
# - Evaluates model performance on the test set and prints metrics.
# - Visualizes distributions and top feature coefficients.
#
# **Output:**
# Performance metrics and visualizations for HLM using PC4 principal components.

# %%
# --- HLM Model for investments using PC4 features and train/test split ---

feature_cols_PC4 = [f'PC4_{i+1}' for i in range(4)]
target_col_PC4 = 'slog_Scope_3_emissions_amount'
cat_cols_PC4 = ['Countries', 'Year', 'account_id', 'Primary_activity']
all_model_vars_PC4 = feature_cols_PC4 + [target_col_PC4] + cat_cols_PC4

# Filter for required columns only
train_df_PC4 = train_df.dropna(subset=all_model_vars_PC4).copy()
test_df_PC4 = test_df.dropna(subset=all_model_vars_PC4).copy()

# Ensure all categorical levels in test are present in train
for cat_col in ['Countries', 'Primary_activity']:
    train_cats = set(train_df_PC4[cat_col].unique())
    n_before = len(test_df_PC4)
    test_df_PC4 = test_df_PC4[test_df_PC4[cat_col].isin(train_cats)]
    n_after = len(test_df_PC4)
    if n_after < n_before:
        print(f"Warning: Dropped {n_before - n_after} test rows with unseen {cat_col} categories.")

if test_df_PC4.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # Model formula (only PC4 features as predictors)
    fixed_effects = (
        ' + '.join(feature_cols_PC4) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_PC4} ~ {fixed_effects}'

    # Fit the mixed-effects model
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_PC4, groups=train_df_PC4['account_id'])
        mdf_PC4 = md.fit(reml=False)
    print(mdf_PC4.summary())

    # Calculate conditional and marginal R²
    var_fixed = np.var(mdf_PC4.fittedvalues)
    var_resid = mdf_PC4.scale
    var_random = mdf_PC4.cov_re.iloc[0, 0] if mdf_PC4.cov_re.shape[0] > 0 else 0.0
    var_random_total = var_random

    r2_marginal = var_fixed / (var_fixed + var_random_total + var_resid)
    r2_conditional = (var_fixed + var_random_total) / (var_fixed + var_random_total + var_resid)

    print(f"Marginal R² (fixed only):      {r2_marginal:.4f}")
    print(f"Conditional R² (fixed+random): {r2_conditional:.4f}")

    # Predict on test set
    test_df_PC4['predicted_log'] = mdf_PC4.predict(test_df_PC4)
    test_df_PC4['predicted'] = np.sign(test_df_PC4['predicted_log']) * (np.expm1(np.abs(test_df_PC4['predicted_log'])))

    # Metrics
    y_true_log = test_df_PC4[target_col_PC4]
    y_pred_log = test_df_PC4['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_PC4['predicted']

    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)

    metrics_text = (
        f"Conditional R²:   {r2_conditional*100:.2f}%\n"
        f"Marginal R²:      {r2_marginal*100:.2f}%\n"
        f"MAPE:             {mape_orig:.2f}%\n"
        f"MAPE(log):        {mape_log:.2f}%\n"
        f"MAE(log):         {mae_log:.2f}\n"
        f"RMSLE:            {rmsle:.2f}\n"
        f"RMSE:             {rmse_orig:.2f}\n"
        f"MAE:              {mae_orig:.2f}"
    )

    print("\ninvestments HLM with PC4 Fixed Effects: Test Set Performance Metrics:")
    print(metrics_text)

    # Feature coefficients
    coef_df = pd.DataFrame({
        'coef': mdf_PC4.params,
        'pvalue': mdf_PC4.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))
    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # Visualization
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("investments HLM (PC4 Fixed Effects): Signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()
    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("investments HLM (PC4 Fixed Effects): Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()
    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    plt.tight_layout()
    plt.show()
    valid_hist_mask = np.isfinite(y_true) & np.isfinite(y_pred) & (y_true > -1) & (y_pred > -1)
    y_true_hist = y_true[valid_hist_mask]
    y_pred_hist = y_pred[valid_hist_mask]
    if len(y_true_hist) > 0 and len(y_pred_hist) > 0:
        min_val = min(y_true_hist.min(), y_pred_hist.min())
        max_val = max(y_true_hist.max(), y_pred_hist.max())
        if (min_val + 1) > 0 and (max_val + 1) > 0:
            log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)
            plt.figure(figsize=(8, 5))
            sns.histplot(y_true_hist, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
            sns.histplot(y_pred_hist, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="HLM Model Predicted")
            plt.xscale("log")
            plt.title("investments HLM (PC4 Fixed Effects): Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
            plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
            plt.ylabel("Density")
            plt.legend()
            plt.tight_layout()
            plt.show()
        else:
            print("Error: min_val or max_val invalid for log scaling.")
    else:
        print("Error: No valid y_true/y_pred values for histogram.")

    # RETURN METRICS FOR SUMMARY TABLE
    PC4_model_metrics = {
        "Model": "HLM PC4",
        "Conditional_R2": r2_conditional,
        "Marginal_R2": r2_marginal,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "MAE_log": mae_log,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "# Obs (train)": len(train_df_PC4),
        "# Obs (test)": len(test_df_PC4),
        "# Obs (train/test)": f"{len(train_df_PC4)}/{len(test_df_PC4)}"
    }
# Out:
# Warning: Dropped 2 test rows with unseen Countries categories.
# Warning: Dropped 3 test rows with unseen Primary_activity categories.
#                                         Mixed Linear Model Regression Results
# ======================================================================================================================
# Model:                           MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                602                   Method:                           ML
# No. Groups:                      214                   Scale:                            1.0483
# Min. group size:                 1                     Log-Likelihood:                   -1078.0200
# Max. group size:                 5                     Converged:                        Yes
# Mean group size:                 2.8
# ----------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 66.863   73.415  0.911 0.362 -77.027 210.752
# C(Countries)[T.Belgium]                                                    3.882    1.639  2.369 0.018   0.670   7.093
# C(Countries)[T.Brazil]                                                     1.244    2.046  0.608 0.543  -2.766   5.254
# C(Countries)[T.Canada]                                                     3.229    1.110  2.910 0.004   1.055   5.404
# C(Countries)[T.China]                                                      2.776    1.270  2.186 0.029   0.287   5.264
# C(Countries)[T.Denmark]                                                    4.627    1.490  3.106 0.002   1.707   7.547
# C(Countries)[T.Finland]                                                    1.221    1.976  0.618 0.537  -2.651   5.093
# C(Countries)[T.France]                                                     2.718    1.142  2.380 0.017   0.480   4.957
# C(Countries)[T.Germany]                                                    0.719    1.306  0.550 0.582  -1.841   3.279
# C(Countries)[T.Ireland]                                                    3.806    2.137  1.781 0.075  -0.382   7.995
# C(Countries)[T.Italy]                                                      4.747    1.453  3.266 0.001   1.898   7.595
# C(Countries)[T.Japan]                                                      2.508    0.952  2.635 0.008   0.642   4.373
# C(Countries)[T.Mexico]                                                     4.466    1.624  2.749 0.006   1.282   7.649
# C(Countries)[T.Netherlands]                                                4.221    1.122  3.761 0.000   2.021   6.421
# C(Countries)[T.New Zealand]                                               -2.585    1.821 -1.420 0.156  -6.154   0.983
# C(Countries)[T.Norway]                                                     3.952    1.241  3.185 0.001   1.520   6.385
# C(Countries)[T.Portugal]                                                   7.488    2.775  2.698 0.007   2.048  12.927
# C(Countries)[T.Singapore]                                                  3.886    2.159  1.800 0.072  -0.345   8.117
# C(Countries)[T.South Africa]                                               3.135    1.306  2.400 0.016   0.575   5.696
# C(Countries)[T.South Korea]                                                1.479    1.048  1.411 0.158  -0.575   3.534
# C(Countries)[T.Spain]                                                      1.388    1.094  1.268 0.205  -0.757   3.532
# C(Countries)[T.Sweden]                                                    -1.633    2.002 -0.816 0.415  -5.557   2.291
# C(Countries)[T.Switzerland]                                               -0.211    1.175 -0.179 0.858  -2.514   2.092
# C(Countries)[T.Thailand]                                                   4.250    2.119  2.006 0.045   0.097   8.404
# C(Countries)[T.USA]                                                        2.522    0.962  2.622 0.009   0.637   4.407
# C(Countries)[T.United Kingdom]                                             2.215    1.096  2.021 0.043   0.067   4.363
# C(Primary_activity)[T.Agriculture, construction & mining machinery]        0.873    3.183  0.274 0.784  -5.365   7.112
# C(Primary_activity)[T.Alcoholic beverages]                                -0.970    2.507 -0.387 0.699  -5.883   3.944
# C(Primary_activity)[T.Animal processing]                                   1.937    2.827  0.685 0.493  -3.603   7.477
# C(Primary_activity)[T.Apparel & footwear design]                           1.260    2.718  0.463 0.643  -4.068   6.588
# C(Primary_activity)[T.Apparel stores]                                      1.193    2.722  0.438 0.661  -4.142   6.529
# C(Primary_activity)[T.Aquaculture]                                        -2.782    2.579 -1.079 0.281  -7.837   2.273
# C(Primary_activity)[T.Asset managers]                                     -0.143    2.402 -0.059 0.953  -4.851   4.565
# C(Primary_activity)[T.Automobiles]                                        -1.810    2.825 -0.641 0.522  -7.346   3.726
# C(Primary_activity)[T.Baked goods & cereals]                               3.348    2.666  1.256 0.209  -1.877   8.573
# C(Primary_activity)[T.Banks]                                              -0.383    2.079 -0.184 0.854  -4.457   3.691
# C(Primary_activity)[T.Biotechnology]                                      -1.071    2.305 -0.465 0.642  -5.589   3.447
# C(Primary_activity)[T.Building sub-contractors]                            1.591    2.564  0.621 0.535  -3.434   6.617
# C(Primary_activity)[T.CCGT generation]                                     1.710    2.275  0.751 0.452  -2.750   6.169
# C(Primary_activity)[T.Commercial services]                                -0.021    2.668 -0.008 0.994  -5.250   5.207
# C(Primary_activity)[T.Communications equipment]                            0.552    2.690  0.205 0.837  -4.720   5.824
# C(Primary_activity)[T.Computer hardware]                                   2.832    2.439  1.161 0.246  -1.948   7.612
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 1.887    2.434  0.775 0.438  -2.884   6.658
# C(Primary_activity)[T.Department stores]                                  -5.942    2.660 -2.234 0.025 -11.155  -0.730
# C(Primary_activity)[T.Discretionary delivery retail]                      -0.427    2.857 -0.149 0.881  -6.026   5.172
# C(Primary_activity)[T.Electrical equipment]                               -0.084    2.194 -0.038 0.970  -4.383   4.216
# C(Primary_activity)[T.Electricity networks]                               -1.578    2.913 -0.542 0.588  -7.288   4.132
# C(Primary_activity)[T.Electronic components]                              -0.544    2.156 -0.252 0.801  -4.771   3.682
# C(Primary_activity)[T.Electronic equipment]                               -2.264    2.190 -1.034 0.301  -6.555   2.028
# C(Primary_activity)[T.Energy infrastructure construction]                 -0.234    2.779 -0.084 0.933  -5.681   5.213
# C(Primary_activity)[T.Engineering services]                                1.371    2.926  0.469 0.639  -4.364   7.107
# C(Primary_activity)[T.Engines & motors]                                    0.069    2.871  0.024 0.981  -5.557   5.696
# C(Primary_activity)[T.Fabricated metal components]                         0.065    2.231  0.029 0.977  -4.307   4.437
# C(Primary_activity)[T.Fast food]                                          -0.282    2.776 -0.102 0.919  -5.723   5.159
# C(Primary_activity)[T.Food & beverage amenities]                          -1.577    2.767 -0.570 0.569  -7.001   3.846
# C(Primary_activity)[T.Food & beverage wholesale]                          -1.674    2.750 -0.609 0.543  -7.063   3.715
# C(Primary_activity)[T.Gas utilities]                                      -0.101    2.396 -0.042 0.966  -4.797   4.596
# C(Primary_activity)[T.Glass products]                                      0.752    2.704  0.278 0.781  -4.547   6.052
# C(Primary_activity)[T.Grain & corn milling]                                1.722    2.834  0.608 0.543  -3.832   7.276
# C(Primary_activity)[T.Health care services]                               -4.313    2.817 -1.531 0.126  -9.834   1.207
# C(Primary_activity)[T.Industrial machinery]                               -3.269    2.669 -1.225 0.221  -8.501   1.963
# C(Primary_activity)[T.Inorganic base chemicals]                            3.721    2.270  1.639 0.101  -0.728   8.171
# C(Primary_activity)[T.Insurance]                                           1.260    2.090  0.603 0.546  -2.836   5.356
# C(Primary_activity)[T.Intermodal transport]                               -1.656    2.670 -0.620 0.535  -6.888   3.577
# C(Primary_activity)[T.Iron & steel]                                        6.211    2.743  2.264 0.024   0.834  11.587
# C(Primary_activity)[T.Logging]                                             1.606    2.667  0.602 0.547  -3.622   6.834
# C(Primary_activity)[T.Logistics - 3rd party]                              -3.739    2.947 -1.269 0.204  -9.514   2.036
# C(Primary_activity)[T.Logistics - transport]                              -4.648    2.888 -1.609 0.108 -10.309   1.013
# C(Primary_activity)[T.Marine freight]                                      3.625    2.682  1.352 0.176  -1.631   8.882
# C(Primary_activity)[T.Marketing]                                           1.344    2.229  0.603 0.546  -3.024   5.712
# C(Primary_activity)[T.Medical equipment]                                  -1.789    2.424 -0.738 0.460  -6.540   2.962
# C(Primary_activity)[T.Metal containers & packaging]                        2.424    2.666  0.909 0.363  -2.801   7.648
# C(Primary_activity)[T.Nitrogenous fertilizers]                             4.166    2.845  1.465 0.143  -1.409   9.741
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         2.546    2.673  0.952 0.341  -2.694   7.785
# C(Primary_activity)[T.Non-residential building construction]               0.038    2.480  0.015 0.988  -4.822   4.898
# C(Primary_activity)[T.Oil & gas marketing & retailing]                    -7.185    3.348 -2.146 0.032 -13.747  -0.622
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       0.798    2.332  0.342 0.732  -3.772   5.368
# C(Primary_activity)[T.Other base chemicals]                                2.213    2.172  1.019 0.308  -2.044   6.471
# C(Primary_activity)[T.Other containers & packaging]                        1.427    2.729  0.523 0.601  -3.922   6.776
# C(Primary_activity)[T.Other food processing]                               0.209    2.300  0.091 0.928  -4.299   4.717
# C(Primary_activity)[T.Other professional services]                        -2.450    2.159 -1.135 0.256  -6.681   1.780
# C(Primary_activity)[T.Other renewable energy equipment]                   -3.086    2.975 -1.037 0.300  -8.916   2.744
# C(Primary_activity)[T.Other renewable generation]                         -7.292    3.791 -1.924 0.054 -14.723   0.138
# C(Primary_activity)[T.Paper products]                                      0.841    2.524  0.333 0.739  -4.105   5.787
# C(Primary_activity)[T.Passenger airlines]                                  1.369    2.206  0.621 0.535  -2.954   5.692
# C(Primary_activity)[T.Passenger rail]                                      1.161    2.815  0.412 0.680  -4.356   6.678
# C(Primary_activity)[T.Personal care & household products]                  0.653    2.141  0.305 0.761  -3.544   4.849
# C(Primary_activity)[T.Pharmaceuticals]                                    -1.578    2.208 -0.715 0.475  -5.905   2.749
# C(Primary_activity)[T.Precious metals & minerals mining]                   0.914    2.307  0.396 0.692  -3.609   5.436
# C(Primary_activity)[T.Print publishing]                                   -1.765    2.368 -0.745 0.456  -6.406   2.876
# C(Primary_activity)[T.Printing services]                                  -1.333    2.670 -0.499 0.618  -6.567   3.901
# C(Primary_activity)[T.REIT]                                               -1.037    2.254 -0.460 0.645  -5.456   3.381
# C(Primary_activity)[T.Residential building construction]                  -1.751    2.295 -0.763 0.446  -6.249   2.748
# C(Primary_activity)[T.Rubber products]                                     1.003    2.295  0.437 0.662  -3.494   5.501
# C(Primary_activity)[T.Semiconductors]                                      2.833    2.808  1.009 0.313  -2.671   8.336
# C(Primary_activity)[T.Software]                                           -2.191    2.660 -0.824 0.410  -7.405   3.022
# C(Primary_activity)[T.Solar energy equipment]                             -0.158    2.683 -0.059 0.953  -5.417   5.100
# C(Primary_activity)[T.Specialist retail]                                  -0.815    2.566 -0.318 0.751  -5.844   4.214
# C(Primary_activity)[T.Specialty chemicals]                                 1.553    2.245  0.692 0.489  -2.847   5.954
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     0.884    2.115  0.418 0.676  -3.262   5.029
# C(Primary_activity)[T.Telecommunications services]                         2.262    2.113  1.070 0.285  -1.880   6.403
# C(Primary_activity)[T.Textiles]                                            0.811    2.954  0.274 0.784  -4.979   6.600
# C(Primary_activity)[T.Tobacco products]                                    2.985    2.310  1.292 0.196  -1.542   7.512
# C(Primary_activity)[T.Transportation infrastructure & other construction]  3.403    2.347  1.450 0.147  -1.197   8.003
# C(Primary_activity)[T.Transportation support services]                     1.146    2.759  0.415 0.678  -4.261   6.553
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -3.930    2.378 -1.653 0.098  -8.590   0.730
# C(Primary_activity)[T.Waste management]                                   -1.889    2.687 -0.703 0.482  -7.155   3.378
# PC4_1                                                                      0.188    0.068  2.753 0.006   0.054   0.322
# PC4_2                                                                     -0.115    0.045 -2.531 0.011  -0.204  -0.026
# PC4_3                                                                     -0.125    0.072 -1.731 0.083  -0.267   0.017
# PC4_4                                                                      0.036    0.070  0.519 0.604  -0.100   0.173
# Year                                                                      -0.029    0.036 -0.805 0.421  -0.101   0.042
# Group Var                                                                  2.674    0.406
# ======================================================================================================================
#
# Marginal R² (fixed only):      0.6358
# Conditional R² (fixed+random): 0.8974
#
# investments HLM with PC4 Fixed Effects: Test Set Performance Metrics:
# Conditional R²:   89.74%
# Marginal R²:      63.58%
# MAPE:             2500.01%
# MAPE(log):        18.31%
# MAE(log):         1.69
# RMSLE:            2.23
# RMSE:             1054166.40
# MAE:              382001.20
#
# Top Influential Features (by p-value):
#                                  coef        pvalue
# Group Var                    2.550622  1.284688e-10
# C(Countries)[T.Netherlands]  4.221290  1.692901e-04
# C(Countries)[T.Italy]        4.746573  1.089089e-03
# C(Countries)[T.Norway]       3.952470  1.446817e-03
# C(Countries)[T.Denmark]      4.627311  1.897853e-03
# C(Countries)[T.Canada]       3.229468  3.608627e-03
# PC4_1                        0.188249  5.907560e-03
# C(Countries)[T.Mexico]       4.465601  5.972559e-03
# C(Countries)[T.Portugal]     7.487764  6.977953e-03
# C(Countries)[T.Japan]        2.507859  8.420948e-03
#
# All feature coefficients sorted by absolute value:
#                                                         coef    pvalue
# C(Countries)[T.Portugal]                            7.487764  0.006978
# C(Primary_activity)[T.Other renewable generation]  -7.292467  0.054415
# C(Primary_activity)[T.Oil & gas marketing & ret... -7.184630  0.031884
# C(Primary_activity)[T.Iron & steel]                 6.210525  0.023565
# C(Primary_activity)[T.Department stores]           -5.942426  0.025460
# ...                                                      ...       ...
# C(Primary_activity)[T.Fabricated metal components]  0.064783  0.976830
# C(Primary_activity)[T.Non-residential building ...  0.037991  0.987776
# PC4_4                                               0.036215  0.603504
# Year                                               -0.029289  0.420561
# C(Primary_activity)[T.Commercial services]         -0.021494  0.993571
#
# [112 rows x 2 columns]

# %% [markdown]
# Now I'll look into hierarchical clustering to determine if that may add value to increasing prediction accuracy.

# %% [markdown]
# ## Investments PC4 Clustering with Train/Test 'Cluster' Feature
#
# - Hierarchical clustering (Ward linkage) on standardized PC4 features.
# - Optimal cluster count selected using silhouette score.
# - Cluster labels assigned to all valid rows in `investments_pca_clusters`.
# - **Appends 'Cluster' feature to both `train_df` and `test_df`** for downstream modeling:
#   - `train_df['Cluster'] = investments_pca_clusters.loc[train_df.index, 'Cluster']`
#   - `test_df['Cluster'] = investments_pca_clusters.loc[test_df.index, 'Cluster']`
# - Includes cluster membership for all train and test rows with valid PC4 features.
# - Visualizes silhouette scores and dendrogram for validation.
#
# **Output:**
# `train_df` and `test_df` now include a 'Cluster' feature for use in modeling and analysis.

# %%
# --- STEP 1: Select PC4 PCA components for clustering ---
pc4_cols = [f'PC4_{i}' for i in range(1, 5)]
X_pc4 = investments_pca[pc4_cols].dropna()
clust_indices = X_pc4.index

# --- STEP 2: Standardize the PC4 data ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_pc4)

# --- STEP 3: Hierarchical clustering (Ward linkage) ---
Z = linkage(X_scaled, method='ward')

# --- STEP 4: Find optimal number of clusters using silhouette score ---
range_n_clusters = range(2, 31)  # 2 to 30 clusters
sil_scores = []

for n_clusters in range_n_clusters:
    labels = fcluster(Z, n_clusters, criterion='maxclust')
    score = silhouette_score(X_scaled, labels)
    sil_scores.append(score)

optimal_n_clusters = range_n_clusters[np.argmax(sil_scores)]
print(f"Optimal number of clusters (highest silhouette score): {optimal_n_clusters}")

# --- Plot silhouette scores ---
plt.figure(figsize=(8,5))
plt.plot(range_n_clusters, sil_scores, marker='o')
plt.title('Silhouette Score by Number of Clusters (Clustering on PC4 Features)')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()

# --- STEP 5: Assign optimal cluster labels ---
labels_optimal = fcluster(Z, optimal_n_clusters, criterion='maxclust')

# --- STEP 6: Append cluster labels back to original DataFrame (only for valid rows) ---
investments_pca_clusters = investments_pca.copy()
investments_pca_clusters['Cluster'] = np.nan  # initialize with NaN
investments_pca_clusters.loc[clust_indices, 'Cluster'] = labels_optimal

# --- Append 'Cluster' feature to train and test DataFrames ---
train_df['Cluster'] = investments_pca_clusters.loc[train_df.index, 'Cluster']
test_df['Cluster'] = investments_pca_clusters.loc[test_df.index, 'Cluster']

# --- Print cluster counts ---
print("Number of observations in each cluster:")
print(pd.Series(labels_optimal).value_counts())

# --- Optionally plot dendrogram (subset for readability) ---
plt.figure(figsize=(12, 6))
sample_size = min(100, len(X_scaled))  # Plot up to 100 samples for clarity
dendrogram(Z, truncate_mode='lastp', p=sample_size, leaf_rotation=90, leaf_font_size=10, show_contracted=True)
plt.title('Hierarchical Clustering Dendrogram (Clustering on PC4 Features, truncated)')
plt.xlabel('Cluster Size')
plt.ylabel('Distance')
plt.tight_layout()
plt.show()
# Out:
# Optimal number of clusters (highest silhouette score): 2
# Number of observations in each cluster:
# 2    763
# 1     38
# Name: count, dtype: int64

# %%
print(train_df.info())
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 683 entries, 0 to 682
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   account_name                   683 non-null    object
#  1   account_id                     683 non-null    int64
#  2   Year                           683 non-null    int64
#  3   Countries                      683 non-null    object
#  4   Primary_activity               683 non-null    object
#  5   Primary_sector                 683 non-null    object
#  6   Market_Cap_USD                 603 non-null    float64
#  7   Revenue_USD                    622 non-null    float64
#  8   ebitda_USD                     622 non-null    float64
#  9   grossProfit_USD                622 non-null    float64
#  10  netIncome_USD                  622 non-null    float64
#  11  cashAndCashEquivalents_USD     622 non-null    float64
#  12  shortTermInvestments_USD       622 non-null    float64
#  13  longTermInvestments_USD        622 non-null    float64
#  14  totalAssets_USD                622 non-null    float64
#  15  totalLiabilities_USD           622 non-null    float64
#  16  totalInvestments_USD           622 non-null    float64
#  17  totalDebt_USD                  622 non-null    float64
#  18  totalEquity_USD                622 non-null    float64
#  19  Scope_3_emissions_amount       683 non-null    float64
#  20  scope_1_2_emissions_amount     683 non-null    float64
#  21  Year_sq                        683 non-null    int64
#  22  PC10_1                         602 non-null    float64
#  23  PC10_2                         602 non-null    float64
#  24  PC10_3                         602 non-null    float64
#  25  PC10_4                         602 non-null    float64
#  26  PC10_5                         602 non-null    float64
#  27  PC10_6                         602 non-null    float64
#  28  PC10_7                         602 non-null    float64
#  29  PC10_8                         602 non-null    float64
#  30  PC10_9                         602 non-null    float64
#  31  PC10_10                        602 non-null    float64
#  32  PC7_1                          602 non-null    float64
#  33  PC7_2                          602 non-null    float64
#  34  PC7_3                          602 non-null    float64
#  35  PC7_4                          602 non-null    float64
#  36  PC7_5                          602 non-null    float64
#  37  PC7_6                          602 non-null    float64
#  38  PC7_7                          602 non-null    float64
#  39  PC4_1                          602 non-null    float64
#  40  PC4_2                          602 non-null    float64
#  41  PC4_3                          602 non-null    float64
#  42  PC4_4                          602 non-null    float64
#  43  slog_Scope_3_emissions_amount  683 non-null    float64
#  44  Cluster                        602 non-null    float64
# dtypes: float64(38), int64(3), object(4)
# memory usage: 245.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 683 to 903
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   account_name                   159 non-null    object
#  1   account_id                     159 non-null    int64
#  2   Year                           159 non-null    int64
#  3   Countries                      159 non-null    object
#  4   Primary_activity               159 non-null    object
#  5   Primary_sector                 159 non-null    object
#  6   Market_Cap_USD                 147 non-null    float64
#  7   Revenue_USD                    144 non-null    float64
#  8   ebitda_USD                     144 non-null    float64
#  9   grossProfit_USD                144 non-null    float64
#  10  netIncome_USD                  144 non-null    float64
#  11  cashAndCashEquivalents_USD     144 non-null    float64
#  12  shortTermInvestments_USD       144 non-null    float64
#  13  longTermInvestments_USD        144 non-null    float64
#  14  totalAssets_USD                144 non-null    float64
#  15  totalLiabilities_USD           144 non-null    float64
#  16  totalInvestments_USD           144 non-null    float64
#  17  totalDebt_USD                  144 non-null    float64
#  18  totalEquity_USD                144 non-null    float64
#  19  Scope_3_emissions_amount       159 non-null    float64
#  20  scope_1_2_emissions_amount     159 non-null    float64
#  21  Year_sq                        159 non-null    int64
#  22  PC10_1                         142 non-null    float64
#  23  PC10_2                         142 non-null    float64
#  24  PC10_3                         142 non-null    float64
#  25  PC10_4                         142 non-null    float64
#  26  PC10_5                         142 non-null    float64
#  27  PC10_6                         142 non-null    float64
#  28  PC10_7                         142 non-null    float64
#  29  PC10_8                         142 non-null    float64
#  30  PC10_9                         142 non-null    float64
#  31  PC10_10                        142 non-null    float64
#  32  PC7_1                          142 non-null    float64
#  33  PC7_2                          142 non-null    float64
#  34  PC7_3                          142 non-null    float64
#  35  PC7_4                          142 non-null    float64
#  36  PC7_5                          142 non-null    float64
#  37  PC7_6                          142 non-null    float64
#  38  PC7_7                          142 non-null    float64
#  39  PC4_1                          142 non-null    float64
#  40  PC4_2                          142 non-null    float64
#  41  PC4_3                          142 non-null    float64
#  42  PC4_4                          142 non-null    float64
#  43  slog_Scope_3_emissions_amount  159 non-null    float64
#  44  Cluster                        142 non-null    float64
# dtypes: float64(38), int64(3), object(4)
# memory usage: 57.1+ KB
# None

# %% [markdown]
# ## Investments HLM Model with PC4 + Cluster Features (Train/Test Split)
#
# - Uses `train_df` and `test_df`, with `Cluster` and signed-log Scope 3 emissions target already included.
# - Filters for required features: PC4 components, Cluster, target, and categorical columns.
# - Ensures all categorical levels in test are present in train.
# - Fits hierarchical mixed-effects model with PC4 features, Cluster (as categorical), country, activity, and year.
# - Evaluates model performance on the test set and prints metrics.
# - Visualizes distributions and top feature coefficients.
#
# **Output:**
# Performance metrics and visualizations for HLM using PC4 principal components and Cluster feature.

# %%
# --- HLM Model for investments using PC4+Cluster features and train/test split ---

feature_cols_pc4_cluster = [f'PC4_{i}' for i in range(1, 5)] + ['Cluster']
target_col = 'slog_Scope_3_emissions_amount'
cat_cols = ['Countries', 'Year', 'account_id', 'Primary_activity']
all_model_vars = feature_cols_pc4_cluster + [target_col] + cat_cols

# Use train_df and test_df, both with 'Cluster' and target already present
train_df_pc4c = train_df.dropna(subset=all_model_vars).copy()
test_df_pc4c = test_df.dropna(subset=all_model_vars).copy()

# Ensure all categorical levels in test are present in train
for cat_col in ['Countries', 'Primary_activity', 'Cluster']:
    train_cats = set(train_df_pc4c[cat_col].unique())
    n_before = len(test_df_pc4c)
    test_df_pc4c = test_df_pc4c[test_df_pc4c[cat_col].isin(train_cats)]
    n_after = len(test_df_pc4c)
    if n_after < n_before:
        print(f"Warning: Dropped {n_before - n_after} test rows with unseen {cat_col} categories.")

if test_df_pc4c.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # Model formula (PC4 features plus Cluster as categorical)
    fixed_effects = (
        ' + '.join([f'C({col})' if col == 'Cluster' else col for col in feature_cols_pc4_cluster]) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col} ~ {fixed_effects}'

    # Fit the mixed-effects model
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_pc4c, groups=train_df_pc4c['account_id'])
        mdf_pc4c = md.fit(reml=False)
    print(mdf_pc4c.summary())

    # Calculate conditional and marginal R²
    var_fixed = np.var(mdf_pc4c.fittedvalues)
    var_resid = mdf_pc4c.scale
    var_random = mdf_pc4c.cov_re.iloc[0, 0] if mdf_pc4c.cov_re.shape[0] > 0 else 0.0
    var_random_total = var_random

    r2_marginal = var_fixed / (var_fixed + var_random_total + var_resid)
    r2_conditional = (var_fixed + var_random_total) / (var_fixed + var_random_total + var_resid)

    print(f"Marginal R² (fixed only):      {r2_marginal:.4f}")
    print(f"Conditional R² (fixed+random): {r2_conditional:.4f}")

    # Predict on test set
    test_df_pc4c['predicted_log'] = mdf_pc4c.predict(test_df_pc4c)
    test_df_pc4c['predicted'] = np.sign(test_df_pc4c['predicted_log']) * (np.expm1(np.abs(test_df_pc4c['predicted_log'])))

    # Metrics
    y_true_log = test_df_pc4c[target_col]
    y_pred_log = test_df_pc4c['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_pc4c['predicted']

    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)

    metrics_text = (
        f"Conditional R²:   {r2_conditional*100:.2f}%\n"
        f"Marginal R²:      {r2_marginal*100:.2f}%\n"
        f"MAPE:             {mape_orig:.2f}%\n"
        f"MAPE(log):        {mape_log:.2f}%\n"
        f"MAE(log):         {mae_log:.2f}\n"
        f"RMSLE:            {rmsle:.2f}\n"
        f"RMSE:             {rmse_orig:.2f}\n"
        f"MAE:              {mae_orig:.2f}"
    )

    print("\ninvestments HLM with PC4+Cluster Fixed Effects: Test Set Performance Metrics:")
    print(metrics_text)

    # Feature coefficients
    coef_df = pd.DataFrame({
        'coef': mdf_pc4c.params,
        'pvalue': mdf_pc4c.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))
    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # Visualization
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("investments HLM (PC4+Cluster): Signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()
    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='HLM Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("investments HLM (PC4+Cluster): Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()
    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))
    plt.tight_layout()
    plt.show()
    valid_hist_mask = np.isfinite(y_true) & np.isfinite(y_pred) & (y_true > -1) & (y_pred > -1)
    y_true_hist = y_true[valid_hist_mask]
    y_pred_hist = y_pred[valid_hist_mask]
    if len(y_true_hist) > 0 and len(y_pred_hist) > 0:
        min_val = min(y_true_hist.min(), y_pred_hist.min())
        max_val = max(y_true_hist.max(), y_pred_hist.max())
        if (min_val + 1) > 0 and (max_val + 1) > 0:
            log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)
            plt.figure(figsize=(8, 5))
            sns.histplot(y_true_hist, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
            sns.histplot(y_pred_hist, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="HLM Model Predicted")
            plt.xscale("log")
            plt.title("investments HLM (PC4+Cluster): Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
            plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
            plt.ylabel("Density")
            plt.legend()
            plt.tight_layout()
            plt.show()
        else:
            print("Error: min_val or max_val invalid for log scaling.")
    else:
        print("Error: No valid y_true/y_pred values for histogram.")

    # RETURN METRICS FOR SUMMARY TABLE
    pc4_cluster_model_metrics = {
        "Model": "HLM PC4+Cluster",
        "Conditional_R2": r2_conditional,
        "Marginal_R2": r2_marginal,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "MAE_log": mae_log,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "# Obs (train)": len(train_df_pc4c),
        "# Obs (test)": len(test_df_pc4c),
        "# Obs (train/test)": f"{len(train_df_pc4c)}/{len(test_df_pc4c)}"
    }
# Out:
# Warning: Dropped 2 test rows with unseen Countries categories.
# Warning: Dropped 3 test rows with unseen Primary_activity categories.
#                                         Mixed Linear Model Regression Results
# ======================================================================================================================
# Model:                           MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                602                   Method:                           ML
# No. Groups:                      214                   Scale:                            1.0485
# Min. group size:                 1                     Log-Likelihood:                   -1077.9547
# Max. group size:                 5                     Converged:                        Yes
# Mean group size:                 2.8
# ----------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 69.046   73.668  0.937 0.349 -75.340 213.432
# C(Cluster)[T.2.0]                                                         -0.208    0.575 -0.361 0.718  -1.336   0.920
# C(Countries)[T.Belgium]                                                    3.879    1.638  2.368 0.018   0.668   7.089
# C(Countries)[T.Brazil]                                                     1.257    2.045  0.615 0.539  -2.751   5.266
# C(Countries)[T.Canada]                                                     3.234    1.109  2.915 0.004   1.060   5.408
# C(Countries)[T.China]                                                      2.796    1.270  2.201 0.028   0.307   5.286
# C(Countries)[T.Denmark]                                                    4.626    1.489  3.107 0.002   1.708   7.545
# C(Countries)[T.Finland]                                                    1.201    1.975  0.608 0.543  -2.671   5.073
# C(Countries)[T.France]                                                     2.725    1.142  2.387 0.017   0.487   4.962
# C(Countries)[T.Germany]                                                    0.723    1.305  0.554 0.580  -1.836   3.281
# C(Countries)[T.Ireland]                                                    3.809    2.136  1.783 0.075  -0.377   7.995
# C(Countries)[T.Italy]                                                      4.756    1.453  3.274 0.001   1.909   7.603
# C(Countries)[T.Japan]                                                      2.498    0.952  2.624 0.009   0.632   4.363
# C(Countries)[T.Mexico]                                                     4.473    1.624  2.755 0.006   1.291   7.655
# C(Countries)[T.Netherlands]                                                4.213    1.122  3.754 0.000   2.013   6.412
# C(Countries)[T.New Zealand]                                               -2.578    1.820 -1.417 0.157  -6.145   0.988
# C(Countries)[T.Norway]                                                     3.944    1.241  3.180 0.001   1.513   6.376
# C(Countries)[T.Portugal]                                                   7.453    2.776  2.685 0.007   2.012  12.893
# C(Countries)[T.Singapore]                                                  3.902    2.158  1.808 0.071  -0.328   8.133
# C(Countries)[T.South Africa]                                               3.127    1.306  2.394 0.017   0.567   5.686
# C(Countries)[T.South Korea]                                                1.477    1.048  1.410 0.159  -0.576   3.531
# C(Countries)[T.Spain]                                                      1.380    1.094  1.262 0.207  -0.764   3.524
# C(Countries)[T.Sweden]                                                    -1.678    2.005 -0.837 0.403  -5.607   2.251
# C(Countries)[T.Switzerland]                                               -0.201    1.175 -0.171 0.864  -2.504   2.102
# C(Countries)[T.Thailand]                                                   4.242    2.118  2.002 0.045   0.090   8.394
# C(Countries)[T.USA]                                                        2.535    0.962  2.635 0.008   0.649   4.420
# C(Countries)[T.United Kingdom]                                             2.217    1.095  2.024 0.043   0.070   4.364
# C(Primary_activity)[T.Agriculture, construction & mining machinery]        0.972    3.193  0.304 0.761  -5.286   7.230
# C(Primary_activity)[T.Alcoholic beverages]                                -0.927    2.509 -0.369 0.712  -5.843   3.990
# C(Primary_activity)[T.Animal processing]                                   1.982    2.828  0.701 0.483  -3.561   7.524
# C(Primary_activity)[T.Apparel & footwear design]                           1.303    2.720  0.479 0.632  -4.027   6.634
# C(Primary_activity)[T.Apparel stores]                                      1.257    2.727  0.461 0.645  -4.087   6.602
# C(Primary_activity)[T.Aquaculture]                                        -2.749    2.580 -1.066 0.287  -7.805   2.307
# C(Primary_activity)[T.Asset managers]                                     -0.116    2.402 -0.048 0.962  -4.824   4.593
# C(Primary_activity)[T.Automobiles]                                        -1.741    2.830 -0.615 0.538  -7.288   3.805
# C(Primary_activity)[T.Baked goods & cereals]                               3.398    2.668  1.273 0.203  -1.832   8.627
# C(Primary_activity)[T.Banks]                                              -0.383    2.078 -0.184 0.854  -4.455   3.690
# C(Primary_activity)[T.Biotechnology]                                      -1.015    2.309 -0.439 0.660  -5.541   3.511
# C(Primary_activity)[T.Building sub-contractors]                            1.613    2.564  0.629 0.529  -3.412   6.637
# C(Primary_activity)[T.CCGT generation]                                     1.756    2.278  0.771 0.441  -2.709   6.221
# C(Primary_activity)[T.Commercial services]                                 0.034    2.671  0.013 0.990  -5.200   5.269
# C(Primary_activity)[T.Communications equipment]                            0.573    2.689  0.213 0.831  -4.698   5.844
# C(Primary_activity)[T.Computer hardware]                                   2.867    2.440  1.175 0.240  -1.914   7.649
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 1.941    2.438  0.796 0.426  -2.837   6.720
# C(Primary_activity)[T.Department stores]                                  -5.894    2.662 -2.215 0.027 -11.111  -0.678
# C(Primary_activity)[T.Discretionary delivery retail]                      -0.371    2.860 -0.130 0.897  -5.976   5.234
# C(Primary_activity)[T.Electrical equipment]                               -0.011    2.202 -0.005 0.996  -4.327   4.305
# C(Primary_activity)[T.Electricity networks]                               -1.553    2.913 -0.533 0.594  -7.261   4.156
# C(Primary_activity)[T.Electronic components]                              -0.489    2.161 -0.227 0.821  -4.725   3.746
# C(Primary_activity)[T.Electronic equipment]                               -2.206    2.194 -1.005 0.315  -6.507   2.095
# C(Primary_activity)[T.Energy infrastructure construction]                 -0.199    2.779 -0.072 0.943  -5.647   5.249
# C(Primary_activity)[T.Engineering services]                                1.419    2.928  0.484 0.628  -4.320   7.158
# C(Primary_activity)[T.Engines & motors]                                    0.112    2.872  0.039 0.969  -5.517   5.741
# C(Primary_activity)[T.Fabricated metal components]                         0.119    2.235  0.053 0.957  -4.261   4.499
# C(Primary_activity)[T.Fast food]                                          -0.272    2.775 -0.098 0.922  -5.711   5.167
# C(Primary_activity)[T.Food & beverage amenities]                          -1.528    2.769 -0.552 0.581  -6.956   3.900
# C(Primary_activity)[T.Food & beverage wholesale]                          -1.588    2.759 -0.576 0.565  -6.995   3.819
# C(Primary_activity)[T.Gas utilities]                                      -0.046    2.400 -0.019 0.985  -4.750   4.657
# C(Primary_activity)[T.Glass products]                                      0.808    2.707  0.299 0.765  -4.498   6.114
# C(Primary_activity)[T.Grain & corn milling]                                1.813    2.844  0.638 0.524  -3.761   7.387
# C(Primary_activity)[T.Health care services]                               -4.280    2.817 -1.520 0.129  -9.801   1.241
# C(Primary_activity)[T.Industrial machinery]                               -3.232    2.670 -1.211 0.226  -8.466   2.001
# C(Primary_activity)[T.Inorganic base chemicals]                            3.767    2.273  1.658 0.097  -0.687   8.222
# C(Primary_activity)[T.Insurance]                                           1.275    2.089  0.610 0.542  -2.820   5.370
# C(Primary_activity)[T.Intermodal transport]                               -1.622    2.670 -0.608 0.544  -6.855   3.611
# C(Primary_activity)[T.Iron & steel]                                        6.264    2.746  2.281 0.023   0.883  11.646
# C(Primary_activity)[T.Logging]                                             1.660    2.670  0.622 0.534  -3.574   6.893
# C(Primary_activity)[T.Logistics - 3rd party]                              -3.700    2.947 -1.255 0.209  -9.477   2.077
# C(Primary_activity)[T.Logistics - transport]                              -4.622    2.888 -1.601 0.109 -10.283   1.038
# C(Primary_activity)[T.Marine freight]                                      3.646    2.681  1.360 0.174  -1.610   8.901
# C(Primary_activity)[T.Marketing]                                           1.403    2.234  0.628 0.530  -2.974   5.781
# C(Primary_activity)[T.Medical equipment]                                  -1.722    2.430 -0.709 0.478  -6.485   3.041
# C(Primary_activity)[T.Metal containers & packaging]                        2.467    2.667  0.925 0.355  -2.761   7.694
# C(Primary_activity)[T.Nitrogenous fertilizers]                             4.226    2.848  1.484 0.138  -1.356   9.809
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         2.575    2.673  0.963 0.335  -2.664   7.815
# C(Primary_activity)[T.Non-residential building construction]               0.090    2.483  0.036 0.971  -4.776   4.956
# C(Primary_activity)[T.Oil & gas marketing & retailing]                    -7.130    3.350 -2.128 0.033 -13.696  -0.564
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       0.830    2.333  0.356 0.722  -3.742   5.402
# C(Primary_activity)[T.Other base chemicals]                                2.270    2.177  1.043 0.297  -1.997   6.538
# C(Primary_activity)[T.Other containers & packaging]                        1.491    2.734  0.545 0.586  -3.868   6.849
# C(Primary_activity)[T.Other food processing]                               0.254    2.302  0.110 0.912  -4.258   4.767
# C(Primary_activity)[T.Other professional services]                        -2.394    2.163 -1.107 0.268  -6.634   1.846
# C(Primary_activity)[T.Other renewable energy equipment]                   -3.008    2.981 -1.009 0.313  -8.851   2.835
# C(Primary_activity)[T.Other renewable generation]                         -7.199    3.798 -1.895 0.058 -14.644   0.245
# C(Primary_activity)[T.Paper products]                                      0.895    2.527  0.354 0.723  -4.058   5.848
# C(Primary_activity)[T.Passenger airlines]                                  1.409    2.207  0.638 0.523  -2.917   5.736
# C(Primary_activity)[T.Passenger rail]                                      1.179    2.814  0.419 0.675  -4.336   6.694
# C(Primary_activity)[T.Personal care & household products]                  0.703    2.145  0.328 0.743  -3.501   4.907
# C(Primary_activity)[T.Pharmaceuticals]                                    -1.524    2.212 -0.689 0.491  -5.859   2.811
# C(Primary_activity)[T.Precious metals & minerals mining]                   0.962    2.310  0.417 0.677  -3.566   5.491
# C(Primary_activity)[T.Print publishing]                                   -1.733    2.369 -0.731 0.464  -6.375   2.910
# C(Primary_activity)[T.Printing services]                                  -1.291    2.672 -0.483 0.629  -6.527   3.946
# C(Primary_activity)[T.REIT]                                               -1.003    2.255 -0.445 0.656  -5.424   3.417
# C(Primary_activity)[T.Residential building construction]                  -1.703    2.298 -0.741 0.459  -6.207   2.800
# C(Primary_activity)[T.Rubber products]                                     1.063    2.300  0.462 0.644  -3.444   5.570
# C(Primary_activity)[T.Semiconductors]                                      2.862    2.808  1.019 0.308  -2.642   8.365
# C(Primary_activity)[T.Software]                                           -2.147    2.662 -0.806 0.420  -7.363   3.070
# C(Primary_activity)[T.Solar energy equipment]                             -0.108    2.685 -0.040 0.968  -5.372   5.155
# C(Primary_activity)[T.Specialist retail]                                  -0.755    2.570 -0.294 0.769  -5.792   4.282
# C(Primary_activity)[T.Specialty chemicals]                                 1.602    2.248  0.713 0.476  -2.805   6.009
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     0.934    2.119  0.441 0.659  -3.218   5.087
# C(Primary_activity)[T.Telecommunications services]                         2.308    2.116  1.091 0.275  -1.840   6.455
# C(Primary_activity)[T.Textiles]                                            0.828    2.953  0.281 0.779  -4.960   6.616
# C(Primary_activity)[T.Tobacco products]                                    3.016    2.310  1.305 0.192  -1.513   7.544
# C(Primary_activity)[T.Transportation infrastructure & other construction]  3.449    2.349  1.468 0.142  -1.156   8.054
# C(Primary_activity)[T.Transportation support services]                     1.193    2.761  0.432 0.666  -4.218   6.604
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -3.911    2.377 -1.645 0.100  -8.570   0.749
# C(Primary_activity)[T.Waste management]                                   -1.843    2.689 -0.685 0.493  -7.112   3.427
# PC4_1                                                                      0.191    0.069  2.775 0.006   0.056   0.325
# PC4_2                                                                     -0.126    0.055 -2.287 0.022  -0.234  -0.018
# PC4_3                                                                     -0.092    0.117 -0.780 0.435  -0.322   0.138
# PC4_4                                                                      0.057    0.091  0.630 0.529  -0.121   0.236
# Year                                                                      -0.030    0.036 -0.831 0.406  -0.102   0.041
# Group Var                                                                  2.671    0.406
# ======================================================================================================================
#
# Marginal R² (fixed only):      0.6359
# Conditional R² (fixed+random): 0.8974
#
# investments HLM with PC4+Cluster Fixed Effects: Test Set Performance Metrics:
# Conditional R²:   89.74%
# Marginal R²:      63.59%
# MAPE:             2502.21%
# MAPE(log):        18.28%
# MAE(log):         1.69
# RMSLE:            2.23
# RMSE:             1052767.69
# MAE:              381198.09
#
# Top Influential Features (by p-value):
#                                  coef        pvalue
# Group Var                    2.547131  1.316912e-10
# C(Countries)[T.Netherlands]  4.212846  1.738741e-04
# C(Countries)[T.Italy]        4.755990  1.060467e-03
# C(Countries)[T.Norway]       3.944361  1.474944e-03
# C(Countries)[T.Denmark]      4.626351  1.893007e-03
# C(Countries)[T.Canada]       3.233703  3.551612e-03
# PC4_1                        0.190552  5.518914e-03
# C(Countries)[T.Mexico]       4.473082  5.869281e-03
# C(Countries)[T.Portugal]     7.452891  7.254718e-03
# C(Countries)[T.USA]          2.534718  8.417700e-03
#
# All feature coefficients sorted by absolute value:
#                                                         coef    pvalue
# C(Countries)[T.Portugal]                            7.452891  0.007255
# C(Primary_activity)[T.Other renewable generation]  -7.199215  0.058038
# C(Primary_activity)[T.Oil & gas marketing & ret... -7.129735  0.033318
# C(Primary_activity)[T.Iron & steel]                 6.264331  0.022520
# C(Primary_activity)[T.Department stores]           -5.894476  0.026786
# ...                                                      ...       ...
# PC4_4                                               0.057394  0.528726
# C(Primary_activity)[T.Gas utilities]               -0.046343  0.984593
# C(Primary_activity)[T.Commercial services]          0.034238  0.989772
# Year                                               -0.030294  0.406195
# C(Primary_activity)[T.Electrical equipment]        -0.010615  0.996154
#
# [113 rows x 2 columns]

# %% [markdown]
# ## Metrics Table

# %%
# --- Dynamically collect available model metrics for investments PCA models ---
model_metric_names = [
    ("PC10_model_metrics",        "train_df_PC10",     "test_df_PC10",     "mdf_PC10",     "pca10"),
    ("PC7_model_metrics",         "train_df_PC7",      "test_df_PC7",      "mdf_PC7",      "pca7"),
    ("PC4_model_metrics",         "train_df_PC4",      "test_df_PC4",      "mdf_PC4",      "pca4"),
    ("pc4_cluster_model_metrics", "train_df_pc4c",     "test_df_pc4c",     "mdf_pc4c",     "pca4"),
]

metrics_dicts = []
trains = []
tests = []
fits = []
explained_vars = []

for metric_name, train_name, test_name, fit_name, pca_name in model_metric_names:
    if (metric_name in globals() and
        train_name in globals() and
        test_name in globals() and
        fit_name in globals() and
        pca_name in globals()):
        metrics_dicts.append(globals()[metric_name])
        trains.append(globals()[train_name])
        tests.append(globals()[test_name])
        fits.append(globals()[fit_name])
        explained_vars.append(sum(getattr(globals()[pca_name], "explained_variance_ratio_", [np.nan])))

# --- Attach observation counts, convergence status, and explained variance to each dictionary ---
for metrics, train, test, fit_result, explained_var in zip(
        metrics_dicts, trains, tests, fits, explained_vars):
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"
    metrics["Converged"] = "Yes" if getattr(fit_result, "converged", False) else "No"
    metrics["PC Explained Variance"] = explained_var

# --- Add a new row for your "Optimized" model ---
optimized_row = {
    "Model": "Optimized investments HLM",
    "Conditional_R2": 0.9081,
    "Marginal_R2": 0.6283,
    "RMSE": 1151394.92,
    "MAE": 426051.8,
    "MAE_log": 1.56,
    "RMSLE": 2.01,
    "MAPE": 2313.22,
    "# Obs (train/test)": "572/120",
    "PC Explained Variance": np.nan,
    "Converged": "Yes"
}
metrics_dicts.append(optimized_row)

metrics_df = pd.DataFrame(metrics_dicts)

# --- Order columns for summary ---
desired_order = [
    "Model", "PC Explained Variance", "Conditional_R2", "Marginal_R2",
    "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)", "Converged"
]

if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

# --- Format for display ---
metrics_df_display = metrics_df.copy()
if "Conditional_R2" in metrics_df_display.columns:
    metrics_df_display["Conditional_R2"] = (metrics_df_display["Conditional_R2"].astype(float) * 100).map("{:.2f}%".format)
if "Marginal_R2" in metrics_df_display.columns:
    metrics_df_display["Marginal_R2"] = (metrics_df_display["Marginal_R2"].astype(float) * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "PC Explained Variance"]:
    if col in metrics_df_display.columns:
        if col == "PC Explained Variance":
            metrics_df_display[col] = metrics_df_display[col].apply(lambda v: "{:.2%}".format(v) if pd.notnull(v) else "")
        else:
            metrics_df_display[col] = metrics_df_display[col].astype(float).map("{:.2f}".format)

# --- Display in notebook or print ---
try:
    display(metrics_df_display)
except Exception:
    print(metrics_df_display.to_string(index=False))
# Out:
#                        Model PC Explained Variance Conditional_R2 Marginal_R2  \
# 0                   HLM PC10                92.57%         89.71%      64.27%
# 1                    HLM PC7                81.51%         89.68%      64.21%
# 2                    HLM PC4                62.65%         89.74%      63.58%
# 3            HLM PC4+Cluster                62.65%         89.74%      63.59%
# 4  Optimized investments HLM                               90.81%      62.83%
#
#          RMSE        MAE MAE_log RMSLE     MAPE # Obs (train/test) Converged
# 0  1060855.49  385727.09    1.68  2.22  2044.88            602/137       Yes
# 1  1048422.49  381085.46    1.67  2.21  1995.21            602/137       Yes
# 2  1054166.40  382001.20    1.69  2.23  2500.01            602/137       Yes
# 3  1052767.69  381198.09    1.69  2.23  2502.21            602/137       Yes
# 4  1151394.92  426051.80    1.56  2.01  2313.22            572/120       Yes
